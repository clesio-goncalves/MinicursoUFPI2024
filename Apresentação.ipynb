# %% [markdown]
# # Minicurso - Técnicas de Visão Computacional e Aprendizado Profundo para a Classificação de Imagens

# %% [markdown]
# # Sumário
#
# - Introdução
# - Visão Computacional
# - Aprendizado Profundo
# - Estudo de Caso
# - Avaliação dos Resultados
# - Conclusões

# %% [markdown]
# # Introdução

# %% [markdown]
# A visão, como sendo um dos sentidos mais avançados dos seres humanos, é importante para a percepção do mundo em volta. Através deste sentido, as pessoas são capazes de realizar diversas ações e realizar conclusões baseando-se no que enxergam.
#
# A visão, como sendo um dos sentidos mais avançados dos seres humanos, é importante para a percepção do mundo em volta. Através deste sentido, as pessoas são capazes de realizar diversas ações e realizar conclusões baseando-se no que enxergam.
#
# Neste contexto, a Visão Computacional tem por objetivo simular o olho humano dentro de um sistema computacional para realizar análises e aprender padrões a partir de entradas visuais. Sendo assim, o ato de tentar replicar comportamentos e percepções dos sentidos humanos caracteriza essa área como um ramo da Inteligência Artificial (IA).
#
# Tendo isso em vista, o objetivo deste minicurso é apresentar, de forma prática, os principais conceitos e tecnologias a respeito deste domínio para a análise e classificação de imagens.

# %% [markdown]
# # Visão Computacional

# %% [markdown]
# A visão computacional é uma área da Inteligência Artificial que busca analisar, interpretar
# e extrair informações relevantes de imagens e/ou vídeos para que decisões possam ser
# tomadas, ou para gerar dados relevantes para uma aplicação futura. Com isso é possível
# distingui-las, classificá-las e agrupá-las. Na figura 1.1, podemos observar algumas das
# principais tarefas realizadas utilizando a visão computacional.
#
# ![title](imagens/cv.png)
#
# Diferença entre as áreas de conhecimentos:
#
# ![title](imagens/vpc.png)

# %% [markdown]
# # Aprendizado Profundo

# %% [markdown]
# - Áreas de conhecimentos da inteligência artificial
#
# ![title](imagens/ia.png)
#
# - Convoluções
#
# ![title](imagens/conv.png)
#
# - Pooling
#
# ![title](imagens/pooling.png)
#
# - Estrutura de uma CNN
#
# ![title](imagens/cnn.png)

# %% [markdown]
# # Transferência de Aprendizado e Ajuste Fino

# %% [markdown]
# Segundo [Fchollet 2020], no contexto de DL, o guia geral para realizar a apren-
# dizagem por transferência é o seguinte:
#
# 1. Reutilizar todas as camadas de um modelo pré-treinado (uma CNN pré-treinada,
# por exemplo);
#
# 2. Congelar todas essas camadas para evitar perder as informações que foram aprendi-
# das durante as próximas iterações de treinamento. As camadas congeladas evitam
# que os pesos dos neurônios sejam atualizados;
#
# 3. Adicionar novas camadas totalmente conectadas sob as camadas congeladas. Com
# isso essas novas camadas irão transformar o aprendizado das camadas congeladas
# em previsões para o novo conjunto imagens;
#
# 4. Treinar essas novas camadas recém adicionadas no novo conjunto de imagens.
#
# A técnica de ajuste fino consiste em descongelar todas as camadas do modelo
# pré-treinado, ou apenas as camadas finais, e retreiná-lo com outro conjunto de dados
# utilizando uma taxa de aprendizado baixa para evitar o super ajuste. Essa técnica pode al-
# cançar melhorias significativas nos resultados do novo modelo de classificação, adaptando
# as características pré-treinadas aos novos dados [Fchollet 2020].

# %% [markdown]
# # Estudo de Caso

# %% [markdown]
# Estudo de caso que consiste em 4 etapas:
#
# 1) Aquisição de um conjunto de imagens de varíola dos macacos, sarampo, catapora e casos normais;
# 2) Utilização de técnicas de pré-processamento de imagens;
# 3) Aplicação da técnica de aumento de dados aleatório para aumentar a generalização do modelo de classificação;
# 4) Treinamento de modelos da CNN para extração de atributos e classificação das imagens.
#
# ![title](imagens/classificacao.png)

# %% [markdown]
# # Aquisição de Imagens

# %% [markdown]
# Para as tarefas envolvendo o aprendizado profundo em qualquer contexto é necessária a
# aquisição de imagens que consigam representar as classes de problemas há serem estu-
# dados. Com o intuito de trazer um estudo de caso, utilizamos um conjunto de imagens
# baseado em imagens de pele disponível publicamente [Bala 2022].
#
# O conjunto de dados é dividido em quatro classes: varíola dos macacos, catapora,
# sarampo e saudáveis, contendo 107, 91, 279 e 293 imagens, respectivamente. Esse con-
# junto de dados é utilizado apenas para fins educacionais e de pesquisas.
#
# ![title](imagens/classes.png)
#
# - a) Varíola dos macacos
# - b) Catapora
# - c) Sarampo
# - d) Outros (saudáveis)

# %% [markdown]
# # Aumento de Dados

# %% [markdown]
# Nesse processo de classificação, utiliza-se quatro técnicas de aumento de dados:
#
# 1) espelhamento aleatório da imagem, nos eixos horizontal e vertical;
# 2) rotação aleatória da imagem variando de 0° a 90° graus, no sentido horário e anti-horário, esse intervalo foi aplicado para preservar as características da imagem;
# 3) zoom aleatório variando de 0% a 10%, pois valores mais altos podem causar a perda de partes importantes da imagem, como as amastigotas;
# 4) contraste da imagem ajustado por um valor de fator de 0,2, o fator de contraste é escolhido aleatoriamente entre [1,0 - fator, 1,0 + fator]. O contraste é ajustado de forma independente para cada canal de cor de cada imagem durante o treinamento.

# %% [markdown]
# # Extração de Atributos e Classificação

# %% [markdown]
# ![title](imagens/tabelamodel.png)
#
# ![title](imagens/parametros.png)

# %% [markdown]
# Para avaliar a metodologia completa e comprovar a generalização dos modelos
# na base de teste são utilizadas algumas métricas que são amplamente difundidas na liter-
# atura, temos então as seguintes métricas: Acurácia; Kappa; Recall; Precisão; F1-Score;
# Especificidade e AUC.
#
# Acurácia [Story and Congalton 1986](Acc): é a média global dos acertos para o
# modelo ao classificar as classes. A Acurácia se da pela Equação 1.
#
# ![title](imagens/acc.png)
#
# Kappa [Cohen 1968]: a acurácia pode não ser uma boa métrica de avaliação para
# dados que possam conter classes com quantidade de amostras desbalanceados, então para
# resolver isso podemos utilizar a métrica Kappa, dada pela Equação 2.
#
# ![title](imagens/kappa.png)
#
# Recall (Sensibilidade): taxa real positiva (TPR), taxa de acerto ou sensibilidade,
# de um classificador representa as amostras classificadas corretamente para o número total
# de amostras positivas [Tharwat 2021]. Ela pode ser obtida pela equação 3.
#
# ![title](imagens/recall.png)
#
# Precisão [David L. Olson 2008]: essa métrica verifica quantas observações o mod-
# elo classificou de forma correta como pertencente a uma classe. A Precisão se da pela
# Equação 4.
#
# ![title](imagens/prec.png)
#
# F1-Score [Rijsbergen 1979](F1): a métrica F1-Score é a média harmônica entre
# as métricas, Recall e Precisão, ou seja, ela resume as informações dessas duas métricas.
# A formula dessa métrica é dada pela Equação 5.
#
# ![title](imagens/f1.png)
#
# Especificidade (ESP): é expressa como a razão das amostras negativas correta-
# mente classificadas para o número total de amostras negativas. Assim, a especificidade
# representa a proporção das amostras negativas corretamente classificadas [Tharwat 2021].
# Podemos calculá-la usando a Equação 6.
#
# ![title](imagens/esp.png)
#
# A curva ROC (Receiver Operating Characteristics) é um gráfico de linha que
# mostra a capacidade de diagnóstico de um classificador, visualizando seu desempenho
# com diferentes limiares. A área sob a curva ROC, do inglês Area Under the Curve
# (AUC), mede toda a área bidimensional abaixo da curva ROC. Essa curva representa
# dois parâmetros: Taxa de Verdadeiro Positivo (TPR) e Taxa de Falso Positivo (FPR)
# [Taha and Hanbury 2015].
#
# ![title](imagens/roc.png)

# %%
# Versão da Linguagem Python
from platform import python_version
print('Versão da Linguagem Python Usada Neste Jupyter Notebook:', python_version())
# Out:
# Versão da Linguagem Python Usada Neste Jupyter Notebook: 3.8.5

# %% [markdown]
# ## GPU

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"]="2"

# %%
tf_device='/gpu:2'

# %% [markdown]
# ## Bibliotecas

# %%
# Imports 

# Imports para manipulação e visualização de dados
import pandas as pd 
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

# Imports para manipulação de imagens
import os 
import sklearn
from PIL import Image
from sklearn.model_selection import train_test_split

# Imports para cálculo de métricas e utilitários
from sklearn.metrics import cohen_kappa_score, accuracy_score, f1_score, precision_score, recall_score, roc_auc_score
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import LabelBinarizer

# Imports para Deep Learning
#import plaidml
#import plaidml.keras
import tensorflow as tf
import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Dense, Dropout, GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam, SGD
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint, Callback

# Redes Neurais
from keras.applications.inception_v3 import InceptionV3
from keras.applications.densenet import DenseNet201
from keras.applications.xception import Xception
from keras.applications.inception_resnet_v2 import InceptionResNetV2
from keras.applications.nasnet import NASNetLarge
from keras.applications.resnet_v2 import ResNet152V2
from keras.applications.vgg16 import VGG16
from keras.applications.resnet50 import ResNet50

# As novas versões do Pandas e Matplotlib trazem diversas mensagens de aviso ao desenvolvedor. Vamos desativar isso.
import sys
import warnings
import matplotlib.cbook
if not sys.warnoptions:
    warnings.simplefilter("ignore")
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings("ignore", category=matplotlib.cbook.mplDeprecation)

# %matplotlib inline

# %%
# Versões dos pacotes usados neste jupyter notebook
# %reload_ext watermark
# %watermark -a "SINFO" --iversions
# Out:
# Author: SINFO
#
# sys       : 3.8.5 (default, Sep  4 2020, 07:30:14)
# [GCC 7.3.0]
# keras     : 2.4.3
# sklearn   : 0.24.1
# pandas    : 1.2.3
# tensorflow: 2.4.1
# matplotlib: 3.3.4
# PIL       : 8.1.2
# numpy     : 1.19.2

# %% [markdown]
# ## Parâmetros

# %%
# Dados de entrada
#PATH_IMAGES = 'dataset/Monkeypox_2_classes/Original_Images/Original_Images/'
PATH_IMAGES = 'dataset/Monkeypox_4_classes/dataset/'

# Parâmetros do treinamento
BATCH_SIZE = 8
SEED = 42

# K-fold
N_SPLIT = 4

# %%
# Parâmetros treinamento
epocas_treinamento = 20
base_learning_rate = 0.0001

epocas_ajuste_fino = 10
total_epocas = epocas_treinamento + epocas_ajuste_fino

# %% [markdown]
# # Dataset

# %%
#CATEGORIAS = ['Monkey Pox', 'Others']
CATEGORIAS = ['Chickenpox', 'Measles', 'Monkeypox', 'Normal']
NUM_CATEGORIAS = len(CATEGORIAS)
NUM_CATEGORIAS
# Out:
# 4

# %%
for category in CATEGORIAS:
    print('{} {} images'.format(category, len(os.listdir(os.path.join(PATH_IMAGES, category)))))
# Out:
# Chickenpox 108 images
# Measles 91 images
# Monkeypox 279 images
# Normal 293 images

# %%
dataset = []
for category in CATEGORIAS:
    for file in os.listdir(os.path.join(PATH_IMAGES, category)):
        dataset.append(['{}/{}'.format(category, file), category])
dataset = pd.DataFrame(dataset, columns=['arquivo', 'categoria'])
dataset.shape
# Out:
# (771, 2)

# %%
dataset
# Out:
#                          arquivo   categoria
# 0    Chickenpox/chickenpox49.png  Chickenpox
# 1    Chickenpox/chickenpox13.png  Chickenpox
# 2    Chickenpox/chickenpox41.png  Chickenpox
# 3    Chickenpox/chickenpox61.png  Chickenpox
# 4    Chickenpox/chickenpox39.png  Chickenpox
# ..                           ...         ...
# 766          Normal/normal89.png      Normal
# 767          Normal/normal47.png      Normal
# 768          Normal/normal37.png      Normal
# 769          Normal/normal55.png      Normal
# 770         Normal/normal290.png      Normal
#
# [771 rows x 2 columns]

# %%
# Definindo X e Y
dataset_x = dataset.arquivo
dataset_y = dataset.categoria

# %% [markdown]
# # Leitura dos dados

# %%
#Initializing Data Generators
datagen = ImageDataGenerator()

# train_datagen = ImageDataGenerator(rescale = 1.0/255,
#                                     zoom_range = 0.2, 
#                                     horizontal_flip = True, 
#                                     vertical_flip = True,
#                                     rotation_range = 90,
#                                     brightness_range = (-0.1, 0.1))

# %%
# Carrega os dados de treino, validação e testes
def leitura_dados(img_size):
    train_dataset = datagen.flow_from_dataframe(dataframe = train_df, 
                                                      directory = PATH_IMAGES,
                                                      x_col = "arquivo", 
                                                      y_col = "categoria",
                                                      class_mode = "categorical",
                                                      target_size = img_size, 
                                                      batch_size = BATCH_SIZE,
                                                      seed = SEED,
                                                      shuffle = True)

    val_dataset = datagen.flow_from_dataframe(dataframe = val_df, 
                                                      directory = PATH_IMAGES,
                                                      x_col = "arquivo", 
                                                      y_col = "categoria",
                                                      class_mode = "categorical",
                                                      target_size = img_size, 
                                                      batch_size = BATCH_SIZE,
                                                      shuffle = False)

    test_dataset = datagen.flow_from_dataframe(dataframe = test_df, 
                                                      directory = PATH_IMAGES,
                                                      x_col = "arquivo", 
                                                      y_col = "categoria",
                                                      class_mode = "categorical",
                                                      target_size = img_size, 
                                                      batch_size = BATCH_SIZE,
                                                      shuffle = False)
    
    return train_dataset, val_dataset, test_dataset

# %% [markdown]
# # Métricas

# %%
# Cria data frame de resultados
colunas_dataframe = ['model', 'kappa', 'accuracy', 'recall', 'precision', 'f1', 'specificity', 'roc']
resultados = pd.DataFrame(columns = colunas_dataframe)

def metrics_multi_class(y_true, y_pred):
    '''
        fonte: https://towardsdatascience.com/multi-class-classification-extracting-performance-metrics-from-the-confusion-matrix-b379b427a872
    '''
    
    global resultados
    
    cnf_matrix = confusion_matrix(y_true,y_pred)

    fp = (cnf_matrix.sum(axis=0) - np.diag(cnf_matrix)).astype(float)
    fn = (cnf_matrix.sum(axis=1) - np.diag(cnf_matrix)).astype(float)
    tp = (np.diag(cnf_matrix)).astype(float)
    tn = (cnf_matrix.sum() - (fp + fn + tp)).astype(float)
    
    weights = np.sum(cnf_matrix, axis=1)
    specificity_array = (tn / (tn + fp))
    specificity = np.sum(specificity_array * weights) / np.sum(weights)
    
    kappa = cohen_kappa_score(y_true, y_pred)
    accuracy = accuracy_score(y_true, y_pred)
    recall = recall_score(y_true, y_pred, average='weighted') # sensibility
    precision = precision_score(y_true, y_pred, average='weighted')
    f1 = f1_score(y_true, y_pred, average='weighted')
    
    # ROC
    lb = LabelBinarizer()
    lb.fit(y_true)
    true = lb.transform(y_true)
    pred = lb.transform(y_pred)
    roc = roc_auc_score(true, pred)
    
    metricas = {'model': models[rede].name, 
                'kappa': kappa,
                'accuracy': accuracy,
                'recall': recall,
                'precision': precision,
                'f1': f1,
                'specificity':specificity,
                'roc': roc}
    
    print(metricas)
    
    resultados = resultados.append(metricas, ignore_index=True)

# %%
import itertools

# Função para a Matriz de Confusão
def plot_confusion_matrix(normalize = False,
                          title = 'Matriz de Confusão',
                          cmap = plt.cm.Blues):
    
    classes = CATEGORIAS
    cm = confusion_matrix(y_true, y_pred)
    
    # Se normalize = True, obtemos a matriz de confusão com dados normalizados
    if normalize:
        cm = cm.astype('float') / cm.sum(axis = 1)[:, np.newaxis]
        print("Matriz de Confusão Normalizada")
    else:
        print('Matriz de Confusão Sem Normalização')

    # Mostramos a Matriz de Confusão
    #print(cm)

    # Plot
    plt.imshow(cm, interpolation = 'nearest', cmap = cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation = 45)
    plt.yticks(tick_marks, classes)
    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    
    # Plot do texto
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt), 
                 horizontalalignment = "center",
                 color = "white" if cm[i, j] > thresh else "black")

    plt.ylabel('Label Verdadeiro')
    plt.xlabel('Label Previsto')
    plt.tight_layout()
    plt.show()

# %% [markdown]
# # Modelo

# %%
# leitura dos pesos pré-treinados da ImageNet
# Não inclui as camadas de classificação no topo, ideal para extração de features
models = [
    VGG16(weights='imagenet', input_shape=(224, 224, 3), include_top=False),
    DenseNet201(weights = "imagenet", input_shape = (224, 224, 3), include_top = False),
    InceptionV3(weights='imagenet', input_shape=(299, 299, 3), include_top=False),
    Xception(weights='imagenet', input_shape=(299, 299, 3), include_top=False),
    InceptionResNetV2(weights='imagenet', input_shape=(299, 299, 3), include_top=False),
    NASNetLarge(weights='imagenet', input_shape=(331, 331, 3), include_top=False),
    ResNet152V2(weights='imagenet', input_shape=(224, 224, 3), include_top=False)
]

# Reescala dos valores dos pixels do modelo
processamento_input = [
    keras.applications.vgg16.preprocess_input,
    keras.applications.densenet.preprocess_input,
    keras.applications.inception_v3.preprocess_input,
    keras.applications.xception.preprocess_input,
    keras.applications.inception_resnet_v2.preprocess_input,
    keras.applications.nasnet.preprocess_input,
    keras.applications.resnet_v2.preprocess_input
]

# %%
# Construir um modelo a partir de redes neurais pré-treinadas
def modelo_base(rede):
    
    base_model = models[rede]
    img_size = (base_model.input.shape[1], base_model.input.shape[2])
    
    # Processa as entradas do modelo
    preprocess_input = processamento_input[rede]
    
    return base_model, img_size, preprocess_input

# %%
# Usando aumento de dados aleatórios somente no fit (treinamento)
data_augmentation = keras.Sequential(
    [
        keras.layers.experimental.preprocessing.RandomFlip("horizontal_and_vertical"),
        keras.layers.experimental.preprocessing.RandomRotation(0.9), 
        keras.layers.experimental.preprocessing.RandomZoom(0.1),
        keras.layers.experimental.preprocessing.RandomContrast(0.2)
    ]
)

# %%
# Construir modelo
def build_model():
    
    # Freeze the base_model
    # Congela a base convolucional antes de compilar e treinar o modelo
    # Evita que os pesos em uma determinada camada sejam atualizados durante o treinamento
    base_model.trainable = False
    
    # Arquitetura do modelo básico
    # base_model.summary()

    # Adiciona o cabeçalho de classificação
    # Converter as features do shape `base_model.output_shape[1:] para vectores
    global_average_layer = keras.layers.GlobalAveragePooling2D()

    # Aplica uma camada densa para converter essas features em uma única previsão por imagem
    # Os números > 0.5 preveem a classe 1, os números <= 0.5 preveem a classe 0
    prediction_layer = keras.layers.Dense(4, activation="softmax", name='predictions') # Função de ativação sigmoid adicionada

    # Modelo encadeando as camadas de aumento de dados, reescalonamento, base_model e extrator de features
    img_shape = img_size + (3,)
    inputs = keras.Input(shape = img_shape)
    x = data_augmentation(inputs)
    x = preprocess_input(x)
    x = base_model(x, training=False)
    x = global_average_layer(x)
    x = keras.layers.Dropout(0.2)(x)
    outputs = prediction_layer(x)
    model = keras.Model(inputs, outputs)  
    
    return model

# %%
# Compile o modelo antes de treiná-lo
def compile_model(learning_rate):
    
    # Compilar modelo
    # Não especifiquei o batch_size, pois os dados já estão em conjuntos (batchs)
    model.compile(optimizer = Adam(lr = learning_rate), loss = keras.losses.CategoricalCrossentropy(), metrics = ['categorical_accuracy'])
    
    # model.summary()

# %%
# Definimos um checkpoint para verificar regularmente se a perda em validação diminuiu
# Se a performance melhorar em validação salvamos o modelo
# Podemos ainda optar por salvar o modelo a cada número de épocas
# callbacks
# Redução gradual da taxa de aprendizado (Reduce on Plateau)
def get_callbacks():
    return [EarlyStopping(monitor = 'val_loss', patience = 10, verbose = 1),
            ReduceLROnPlateau(monitor = 'val_loss', factor = 0.1, patience = 5, min_lr = 0.0000001, verbose = 1),
            ModelCheckpoint('modelo/{}.h5'.format(models[rede].name), 
                         verbose = 1, 
                         save_best_only = True, 
                         save_weights_only = True)]

# %%
# Treinamento do modelo
def treinamento_model(qnt_epocas, epoca_inicial):
    
    history = model.fit(train_dataset,
                        epochs = qnt_epocas,
                        initial_epoch = epoca_inicial,
                        validation_data = val_dataset,
                        verbose=1,
                        callbacks = get_callbacks())
    
    return history

# %%
# Curvas de aprendizado da precisão / perda de treinamento e validação ao usar o modelo
def aprendizado_treinamento():
    
    metricas_graficos = ["loss", "categorical_accuracy"]
          
    fig, ax = plt.subplots(len(metricas_graficos), 1, figsize=(10, len(metricas_graficos)*6))
    ax = ax.ravel()
    dados_x = np.arange(1, epocas_treinamento+1, 1)

    for i, met in enumerate(metricas_graficos):        
        ax[i].plot(dados_x, history.history[met], label='Training ' + met)
        ax[i].plot(dados_x, history.history["val_" + met], label='Validation ' + met)
        ax[i].set_title("Training and Validation %s in model %s" %(met, models[rede].name))
        ax[i].set_xlabel("epochs")
        ax[i].set_ylabel(met)
        
        if (i != 0): # loss function
            ax[i].legend(loc='lower right')
        else:
            ax[i].legend(loc='upper right')
    
    return metricas_graficos

# %%
# LIMIAR PARA AJUSTE FINO (OPCIONAL)
# Definir as camadas inferiores como não treináveis
def limiar_ajuste_fino():
    
    # Exibe a quantidade de camadas do modelo base
    # print("Número de camadas no modelo base: ", len(base_model.layers))

    # Ajuste fino desta camada em diante
    fine_tune_at = 100

    # Congele todas as camadas antes da camada 'fine_tune_at'
    for layer in base_model.layers[:fine_tune_at]:
        layer.trainable = False

# %%
# Ajuste fino
def ajuste_fino():
    
    # Foi treinado apenas algumas camadas do modelo. 
    # Os pesos da rede pré-treinada não foram atualizados durante o treinamento.
    # Uma maneira de aumentar ainda mais o desempenho é treinar (ou "ajustar") os pesos das camadas superiores 
    # do modelo pré-treinado junto com o treinamento do classificador adicionado (camada de classificação adicionada)
    # Descongelar as camadas superiores do modelo (descongelar base_model)
    base_model.trainable = True
    
    # Limiar ajuste fino (OPCIONAL)
    limiar_ajuste_fino()
    
    # É necessário recompilar o modelo (para que essas alterações tenham efeito)
    # É importante usar uma taxa de aprendizado mais baixa neste estágio, 
    # pois está usando um modelo muito maior e deseja readaptar os pesos pré-treinados
    compile_model(base_learning_rate/10)
    
    # Retomar o treinamento melhorará sua precisão em alguns pontos percentuais
    # history.epoch[-1] é a última época do ultimo treinamento
    history_fine = treinamento_model(total_epocas, history.epoch[-1]+1)
    
    return history_fine

# %%
# Curvas de aprendizado da precisão / perda de treinamento e validação ao ajustar as últimas camadas do modelo
def aprendizado_ajuste_fino():
    
    fig, ax = plt.subplots(len(metricas_graficos), 1, figsize=(12, len(metricas_graficos)*6))
    ax = ax.ravel()
    dados_x = np.arange(1, len(history.history['loss']) + len(history_fine.history['loss'])+1, 1)

    for i, met in enumerate(metricas_graficos):
        dados_treino = history.history[met] + history_fine.history[met]
        dados_validacao = history.history["val_" + met] + history_fine.history["val_" + met]
        
        ax[i].plot(dados_x, dados_treino, label='Training ' + met)
        ax[i].plot(dados_x, dados_validacao, label='Validation ' + met)
        ax[i].plot([epocas_treinamento, epocas_treinamento], plt.ylim(), label='Start Fine Tuning')
        ax[i].set_title("Training and Validation %s in model %s" %(met, models[rede].name))
        ax[i].set_xlabel("epochs")
        ax[i].set_ylabel(met)
        
        if (i != 0): # loss function
            ax[i].legend(loc='lower right')
        else:
            ax[i].legend(loc='upper right')

# %% [markdown]
# # Treinamento K-fold

# %%
# k-fold
kfold = StratifiedKFold(n_splits = N_SPLIT, shuffle = True, random_state = SEED)

# Contador de iterações do k-fold
iteracao = 1

# K-fold treino e teste de cada divisão
for train_idx, test_idx in list(kfold.split(dataset_x, dataset_y)):
    
    print("\n======================================================")
    print("Iteração {} de {}".format(iteracao, N_SPLIT))
    print("======================================================")
    
    train_df = dataset.iloc[train_idx]
    test_temp = dataset.iloc[test_idx]
    
    # dividir o teste em validação e teste
    val_df, test_df = train_test_split(test_temp, test_size = 0.60, random_state = SEED) # 10% validação e 15% teste
    
    for rede in range(len(models)): # Todos os modelos
        
        print('\nExecutando modelo {}'.format(models[rede].name))
    
        # Modelo base
        base_model, img_size, preprocess_input = modelo_base(rede)

        # Leitura dos dados
        train_dataset, val_dataset, test_dataset = leitura_dados(img_size)

        # Construir modelo
        model = build_model()

        # Compilar Modelo
        compile_model(base_learning_rate)

        # Treinamento do modelo
        history = treinamento_model(epocas_treinamento, 0)

        # Curvas de aprendizado da precisão / perda de treinamento e validação ao usar o modelo
        # metricas_graficos = aprendizado_treinamento()

        # Ajuste fino
        history_fine = ajuste_fino()

        # Curvas de aprendizado da precisão / perda de treinamento e validação ao ajustar as últimas camadas do modelo
        # aprendizado_ajuste_fino()

        # Carrega o melhor modelo
        model.load_weights('modelo/{}.h5'.format(models[rede].name))

        # Obtemos os rótulos verdadeiros
        y_true = np.array(test_dataset.classes)

        # Obtemos os rótulos previstos
        previsoes = model.predict(test_dataset, verbose = 1)
        y_pred = previsoes.argmax(axis=1)

        # Calcula métricas Multiclasse
        metrics_multi_class(y_true, y_pred)

        # Plota matriz de confusão
        # plot_confusion_matrix()

        # Gera o relatório de classificação
        # report = classification_report(y_true, y_pred, target_names = CATEGORIAS)
        # print(report)
        
        # Limpa a sessão
        keras.backend.clear_session()
        
    iteracao = iteracao + 1
# Out:
# ======================================================
# Iteração 1 de 4
# ======================================================
#
# Executando modelo vgg16
# Found 577 validated image filenames belonging to 4 classes.
# Found 77 validated image filenames belonging to 4 classes.
# Found 116 validated image filenames belonging to 4 classes.
# Epoch 1/20
# 73/73 [==============================] - 26s 238ms/step - loss: 4.3655 - categorical_accuracy: 0.2344 - val_loss: 2.7622 - val_categorical_accuracy: 0.3896
#
# Epoch 00001: val_loss improved from inf to 2.76221, saving model to modelo/vgg16.h5
# Epoch 2/20
# 73/73 [==============================] - 2s 22ms/step - loss: 2.9653 - categorical_accuracy: 0.3741 - val_loss: 2.2471 - val_categorical_accuracy: 0.5195
#
# Epoch 00002: val_loss improved from 2.76221 to 2.24707, saving model to modelo/vgg16.h5
# Epoch 3/20
# 73/73 [==============================] - 2s 22ms/step - loss: 2.8289 - categorical_accuracy: 0.4190 - val_loss: 1.9039 - val_categorical_accuracy: 0.5714
#
# Epoch 00003: val_loss improved from 2.24707 to 1.90394, saving model to modelo/vgg16.h5
# Epoch 4/20
# 73/73 [==============================] - 2s 22ms/step - loss: 2.6264 - categorical_accuracy: 0.4539 - val_loss: 1.6828 - val_categorical_accuracy: 0.5974
#
# Epoch 00004: val_loss improved from 1.90394 to 1.68284, saving model to modelo/vgg16.h5
# Epoch 5/20
# 73/73 [==============================] - 2s 23ms/step - loss: 2.1341 - categorical_accuracy: 0.5172 - val_loss: 1.5219 - val_categorical_accuracy: 0.6234
#
# Epoch 00005: val_loss improved from 1.68284 to 1.52190, saving model to modelo/vgg16.h5
# Epoch 6/20
# 73/73 [==============================] - 2s 22ms/step - loss: 2.1526 - categorical_accuracy: 0.5173 - val_loss: 1.3693 - val_categorical_accuracy: 0.6364
#
# Epoch 00006: val_loss improved from 1.52190 to 1.36934, saving model to modelo/vgg16.h5
# Epoch 7/20
# 73/73 [==============================] - 2s 22ms/step - loss: 1.8669 - categorical_accuracy: 0.5761 - val_loss: 1.2539 - val_categorical_accuracy: 0.6494
#
# Epoch 00007: val_loss improved from 1.36934 to 1.25389, saving model to modelo/vgg16.h5
# Epoch 8/20
# 73/73 [==============================] - 2s 22ms/step - loss: 1.9917 - categorical_accuracy: 0.5721 - val_loss: 1.1488 - val_categorical_accuracy: 0.6753
#
# Epoch 00008: val_loss improved from 1.25389 to 1.14876, saving model to modelo/vgg16.h5
# Epoch 9/20
# 73/73 [==============================] - 2s 22ms/step - loss: 1.6645 - categorical_accuracy: 0.6279 - val_loss: 1.0657 - val_categorical_accuracy: 0.7143
#
# Epoch 00009: val_loss improved from 1.14876 to 1.06568, saving model to modelo/vgg16.h5
# Epoch 10/20
# 73/73 [==============================] - 2s 22ms/step - loss: 1.7406 - categorical_accuracy: 0.6101 - val_loss: 0.9867 - val_categorical_accuracy: 0.7273
#
# Epoch 00010: val_loss improved from 1.06568 to 0.98668, saving model to modelo/vgg16.h5
# Epoch 11/20
# 73/73 [==============================] - 2s 22ms/step - loss: 1.3452 - categorical_accuracy: 0.6761 - val_loss: 0.9035 - val_categorical_accuracy: 0.7273
#
# Epoch 00011: val_loss improved from 0.98668 to 0.90354, saving model to modelo/vgg16.h5
# Epoch 12/20
# 73/73 [==============================] - 2s 22ms/step - loss: 1.3161 - categorical_accuracy: 0.6813 - val_loss: 0.8541 - val_categorical_accuracy: 0.7662
#
# Epoch 00012: val_loss improved from 0.90354 to 0.85413, saving model to modelo/vgg16.h5
# Epoch 13/20
# 73/73 [==============================] - 2s 22ms/step - loss: 1.3852 - categorical_accuracy: 0.6560 - val_loss: 0.7890 - val_categorical_accuracy: 0.7792
#
# Epoch 00013: val_loss improved from 0.85413 to 0.78902, saving model to modelo/vgg16.h5
# Epoch 14/20
# 73/73 [==============================] - 2s 22ms/step - loss: 1.1482 - categorical_accuracy: 0.7289 - val_loss: 0.7504 - val_categorical_accuracy: 0.7792
#
# Epoch 00014: val_loss improved from 0.78902 to 0.75040, saving model to modelo/vgg16.h5
# Epoch 15/20
# 73/73 [==============================] - 2s 22ms/step - loss: 1.1569 - categorical_accuracy: 0.6877 - val_loss: 0.7244 - val_categorical_accuracy: 0.7922
#
# Epoch 00015: val_loss improved from 0.75040 to 0.72441, saving model to modelo/vgg16.h5
# Epoch 16/20
# 73/73 [==============================] - 2s 22ms/step - loss: 1.2113 - categorical_accuracy: 0.6921 - val_loss: 0.6975 - val_categorical_accuracy: 0.7922
#
# Epoch 00016: val_loss improved from 0.72441 to 0.69749, saving model to modelo/vgg16.h5
# Epoch 17/20
# 73/73 [==============================] - 2s 22ms/step - loss: 1.2898 - categorical_accuracy: 0.6898 - val_loss: 0.6558 - val_categorical_accuracy: 0.8182
#
# Epoch 00017: val_loss improved from 0.69749 to 0.65582, saving model to modelo/vgg16.h5
# Epoch 18/20
# 73/73 [==============================] - 2s 22ms/step - loss: 1.1399 - categorical_accuracy: 0.7126 - val_loss: 0.6112 - val_categorical_accuracy: 0.8312
#
# Epoch 00018: val_loss improved from 0.65582 to 0.61124, saving model to modelo/vgg16.h5
# Epoch 19/20
# 73/73 [==============================] - 2s 22ms/step - loss: 1.0632 - categorical_accuracy: 0.7392 - val_loss: 0.6128 - val_categorical_accuracy: 0.8312
#
# Epoch 00019: val_loss did not improve from 0.61124
# Epoch 20/20
# 73/73 [==============================] - 2s 22ms/step - loss: 1.0167 - categorical_accuracy: 0.7376 - val_loss: 0.6051 - val_categorical_accuracy: 0.8312
#
# Epoch 00020: val_loss improved from 0.61124 to 0.60508, saving model to modelo/vgg16.h5
# Epoch 21/30
# 73/73 [==============================] - 2s 24ms/step - loss: 1.2865 - categorical_accuracy: 0.6602 - val_loss: 0.6024 - val_categorical_accuracy: 0.8312
#
# Epoch 00021: val_loss improved from inf to 0.60238, saving model to modelo/vgg16.h5
# Epoch 22/30
# 73/73 [==============================] - 2s 22ms/step - loss: 0.9929 - categorical_accuracy: 0.7364 - val_loss: 0.5943 - val_categorical_accuracy: 0.8312
#
# Epoch 00022: val_loss improved from 0.60238 to 0.59431, saving model to modelo/vgg16.h5
# Epoch 23/30
# 73/73 [==============================] - 2s 22ms/step - loss: 1.0045 - categorical_accuracy: 0.7472 - val_loss: 0.5898 - val_categorical_accuracy: 0.8442
#
# Epoch 00023: val_loss improved from 0.59431 to 0.58981, saving model to modelo/vgg16.h5
# Epoch 24/30
# 73/73 [==============================] - 2s 22ms/step - loss: 1.0756 - categorical_accuracy: 0.7323 - val_loss: 0.5838 - val_categorical_accuracy: 0.8442
#
# Epoch 00024: val_loss improved from 0.58981 to 0.58376, saving model to modelo/vgg16.h5
# Epoch 25/30
# 73/73 [==============================] - 2s 22ms/step - loss: 0.8616 - categorical_accuracy: 0.7599 - val_loss: 0.5775 - val_categorical_accuracy: 0.8442
#
# Epoch 00025: val_loss improved from 0.58376 to 0.57754, saving model to modelo/vgg16.h5
# Epoch 26/30
# 73/73 [==============================] - 2s 22ms/step - loss: 0.9645 - categorical_accuracy: 0.7124 - val_loss: 0.5747 - val_categorical_accuracy: 0.8312
#
# Epoch 00026: val_loss improved from 0.57754 to 0.57474, saving model to modelo/vgg16.h5
# Epoch 27/30
# 73/73 [==============================] - 2s 22ms/step - loss: 0.9148 - categorical_accuracy: 0.7501 - val_loss: 0.5712 - val_categorical_accuracy: 0.8442
#
# Epoch 00027: val_loss improved from 0.57474 to 0.57124, saving model to modelo/vgg16.h5
# Epoch 28/30
# 73/73 [==============================] - 2s 22ms/step - loss: 0.8639 - categorical_accuracy: 0.7500 - val_loss: 0.5693 - val_categorical_accuracy: 0.8442
#
# Epoch 00028: val_loss improved from 0.57124 to 0.56930, saving model to modelo/vgg16.h5
# Epoch 29/30
# 73/73 [==============================] - 2s 22ms/step - loss: 1.0299 - categorical_accuracy: 0.7271 - val_loss: 0.5660 - val_categorical_accuracy: 0.8442
#
# Epoch 00029: val_loss improved from 0.56930 to 0.56601, saving model to modelo/vgg16.h5
# Epoch 30/30
# 73/73 [==============================] - 2s 22ms/step - loss: 0.9665 - categorical_accuracy: 0.7444 - val_loss: 0.5639 - val_categorical_accuracy: 0.8571
#
# Epoch 00030: val_loss improved from 0.56601 to 0.56387, saving model to modelo/vgg16.h5
# 15/15 [==============================] - 8s 578ms/step
# {'model': 'vgg16', 'kappa': 0.583438952260245, 'accuracy': 0.7068965517241379, 'recall': 0.7068965517241379, 'precision': 0.7021017689842382, 'f1': 0.7035484000160198, 'specificity': 0.8973375703182033, 'roc': 0.7621782912938535}
#
# Executando modelo densenet201
# Found 577 validated image filenames belonging to 4 classes.
# Found 77 validated image filenames belonging to 4 classes.
# Found 116 validated image filenames belonging to 4 classes.
# Epoch 1/20
# 73/73 [==============================] - 216s 2s/step - loss: 1.5413 - categorical_accuracy: 0.3411 - val_loss: 1.0793 - val_categorical_accuracy: 0.6104
#
# Epoch 00001: val_loss improved from inf to 1.07928, saving model to modelo/densenet201.h5
# Epoch 2/20
# 73/73 [==============================] - 3s 34ms/step - loss: 1.2943 - categorical_accuracy: 0.5104 - val_loss: 0.9059 - val_categorical_accuracy: 0.6753
#
# Epoch 00002: val_loss improved from 1.07928 to 0.90585, saving model to modelo/densenet201.h5
# Epoch 3/20
# 73/73 [==============================] - 2s 33ms/step - loss: 0.9972 - categorical_accuracy: 0.6431 - val_loss: 0.8268 - val_categorical_accuracy: 0.7143
#
# Epoch 00003: val_loss improved from 0.90585 to 0.82680, saving model to modelo/densenet201.h5
# Epoch 4/20
# 73/73 [==============================] - 2s 33ms/step - loss: 0.9391 - categorical_accuracy: 0.6252 - val_loss: 0.7212 - val_categorical_accuracy: 0.7532
#
# Epoch 00004: val_loss improved from 0.82680 to 0.72124, saving model to modelo/densenet201.h5
# Epoch 5/20
# 73/73 [==============================] - 2s 34ms/step - loss: 0.9001 - categorical_accuracy: 0.6578 - val_loss: 0.6596 - val_categorical_accuracy: 0.7792
#
# Epoch 00005: val_loss improved from 0.72124 to 0.65961, saving model to modelo/densenet201.h5
# Epoch 6/20
# 73/73 [==============================] - 2s 33ms/step - loss: 0.8170 - categorical_accuracy: 0.6612 - val_loss: 0.6020 - val_categorical_accuracy: 0.8052
#
# Epoch 00006: val_loss improved from 0.65961 to 0.60199, saving model to modelo/densenet201.h5
# Epoch 7/20
# 73/73 [==============================] - 2s 33ms/step - loss: 0.7060 - categorical_accuracy: 0.7430 - val_loss: 0.5713 - val_categorical_accuracy: 0.8312
#
# Epoch 00007: val_loss improved from 0.60199 to 0.57129, saving model to modelo/densenet201.h5
# Epoch 8/20
# 73/73 [==============================] - 2s 33ms/step - loss: 0.7056 - categorical_accuracy: 0.7381 - val_loss: 0.5368 - val_categorical_accuracy: 0.8442
#
# Epoch 00008: val_loss improved from 0.57129 to 0.53679, saving model to modelo/densenet201.h5
# Epoch 9/20
# 73/73 [==============================] - 2s 34ms/step - loss: 0.5924 - categorical_accuracy: 0.7875 - val_loss: 0.5084 - val_categorical_accuracy: 0.8442
#
# Epoch 00009: val_loss improved from 0.53679 to 0.50841, saving model to modelo/densenet201.h5
# Epoch 10/20
# 73/73 [==============================] - 2s 34ms/step - loss: 0.6121 - categorical_accuracy: 0.7615 - val_loss: 0.4869 - val_categorical_accuracy: 0.8571
#
# Epoch 00010: val_loss improved from 0.50841 to 0.48685, saving model to modelo/densenet201.h5
# Epoch 11/20
# 73/73 [==============================] - 2s 34ms/step - loss: 0.6330 - categorical_accuracy: 0.7909 - val_loss: 0.4640 - val_categorical_accuracy: 0.8701
#
# Epoch 00011: val_loss improved from 0.48685 to 0.46401, saving model to modelo/densenet201.h5
# Epoch 12/20
# 73/73 [==============================] - 2s 33ms/step - loss: 0.5443 - categorical_accuracy: 0.7861 - val_loss: 0.4449 - val_categorical_accuracy: 0.8831
#
# Epoch 00012: val_loss improved from 0.46401 to 0.44490, saving model to modelo/densenet201.h5
# Epoch 13/20
# 73/73 [==============================] - 2s 34ms/step - loss: 0.4893 - categorical_accuracy: 0.8336 - val_loss: 0.4268 - val_categorical_accuracy: 0.8831
#
# Epoch 00013: val_loss improved from 0.44490 to 0.42679, saving model to modelo/densenet201.h5
# Epoch 14/20
# 73/73 [==============================] - 2s 33ms/step - loss: 0.4736 - categorical_accuracy: 0.8342 - val_loss: 0.4172 - val_categorical_accuracy: 0.8831
#
# Epoch 00014: val_loss improved from 0.42679 to 0.41718, saving model to modelo/densenet201.h5
# Epoch 15/20
# 73/73 [==============================] - 2s 33ms/step - loss: 0.5059 - categorical_accuracy: 0.8165 - val_loss: 0.4053 - val_categorical_accuracy: 0.8701
#
# Epoch 00015: val_loss improved from 0.41718 to 0.40534, saving model to modelo/densenet201.h5
# Epoch 16/20
# 73/73 [==============================] - 2s 33ms/step - loss: 0.4602 - categorical_accuracy: 0.8138 - val_loss: 0.3916 - val_categorical_accuracy: 0.8701
#
# Epoch 00016: val_loss improved from 0.40534 to 0.39157, saving model to modelo/densenet201.h5
# Epoch 17/20
# 73/73 [==============================] - 2s 34ms/step - loss: 0.4425 - categorical_accuracy: 0.8649 - val_loss: 0.3809 - val_categorical_accuracy: 0.8701
#
# Epoch 00017: val_loss improved from 0.39157 to 0.38088, saving model to modelo/densenet201.h5
# Epoch 18/20
# 73/73 [==============================] - 2s 34ms/step - loss: 0.4365 - categorical_accuracy: 0.8440 - val_loss: 0.3729 - val_categorical_accuracy: 0.8961
#
# Epoch 00018: val_loss improved from 0.38088 to 0.37286, saving model to modelo/densenet201.h5
# Epoch 19/20
# 73/73 [==============================] - 2s 33ms/step - loss: 0.4443 - categorical_accuracy: 0.8546 - val_loss: 0.3679 - val_categorical_accuracy: 0.8831
#
# Epoch 00019: val_loss improved from 0.37286 to 0.36790, saving model to modelo/densenet201.h5
# Epoch 20/20
# 73/73 [==============================] - 2s 34ms/step - loss: 0.3634 - categorical_accuracy: 0.9101 - val_loss: 0.3603 - val_categorical_accuracy: 0.8831
#
# Epoch 00020: val_loss improved from 0.36790 to 0.36034, saving model to modelo/densenet201.h5
# Epoch 21/30
# 73/73 [==============================] - 225s 2s/step - loss: 0.4145 - categorical_accuracy: 0.8575 - val_loss: 0.2780 - val_categorical_accuracy: 0.9091
#
# Epoch 00021: val_loss improved from inf to 0.27798, saving model to modelo/densenet201.h5
# Epoch 22/30
# 73/73 [==============================] - 6s 79ms/step - loss: 0.1827 - categorical_accuracy: 0.9423 - val_loss: 0.2204 - val_categorical_accuracy: 0.9481
#
# Epoch 00022: val_loss improved from 0.27798 to 0.22038, saving model to modelo/densenet201.h5
# Epoch 23/30
# 73/73 [==============================] - 6s 79ms/step - loss: 0.0875 - categorical_accuracy: 0.9731 - val_loss: 0.2385 - val_categorical_accuracy: 0.9351
#
# Epoch 00023: val_loss did not improve from 0.22038
# Epoch 24/30
# 73/73 [==============================] - 6s 79ms/step - loss: 0.1207 - categorical_accuracy: 0.9490 - val_loss: 0.2324 - val_categorical_accuracy: 0.9351
#
# Epoch 00024: val_loss did not improve from 0.22038
# Epoch 25/30
# 73/73 [==============================] - 6s 80ms/step - loss: 0.0551 - categorical_accuracy: 0.9857 - val_loss: 0.2978 - val_categorical_accuracy: 0.9351
#
# Epoch 00025: val_loss did not improve from 0.22038
# Epoch 26/30
# 73/73 [==============================] - 6s 79ms/step - loss: 0.0722 - categorical_accuracy: 0.9715 - val_loss: 0.2875 - val_categorical_accuracy: 0.9221
#
# Epoch 00026: val_loss did not improve from 0.22038
# Epoch 27/30
# 73/73 [==============================] - 6s 79ms/step - loss: 0.0416 - categorical_accuracy: 0.9776 - val_loss: 0.2648 - val_categorical_accuracy: 0.9351
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-07.
#
# Epoch 00027: val_loss did not improve from 0.22038
# Epoch 28/30
# 73/73 [==============================] - 6s 79ms/step - loss: 0.0288 - categorical_accuracy: 0.9901 - val_loss: 0.2469 - val_categorical_accuracy: 0.9481
#
# Epoch 00028: val_loss did not improve from 0.22038
# Epoch 29/30
# 73/73 [==============================] - 6s 79ms/step - loss: 0.0232 - categorical_accuracy: 0.9988 - val_loss: 0.2428 - val_categorical_accuracy: 0.9481
#
# Epoch 00029: val_loss did not improve from 0.22038
# Epoch 30/30
# 73/73 [==============================] - 6s 79ms/step - loss: 0.0132 - categorical_accuracy: 0.9966 - val_loss: 0.2427 - val_categorical_accuracy: 0.9481
#
# Epoch 00030: val_loss did not improve from 0.22038
# 15/15 [==============================] - 79s 6s/step
# {'model': 'densenet201', 'kappa': 0.8777274164646358, 'accuracy': 0.9137931034482759, 'recall': 0.9137931034482759, 'precision': 0.9169706201239777, 'f1': 0.9124571796614008, 'specificity': 0.9703561328340328, 'roc': 0.9301634194925537}
#
# Executando modelo inception_v3
# Found 577 validated image filenames belonging to 4 classes.
# Found 77 validated image filenames belonging to 4 classes.
# Found 116 validated image filenames belonging to 4 classes.
# Epoch 1/20
# 73/73 [==============================] - 104s 957ms/step - loss: 1.4505 - categorical_accuracy: 0.2951 - val_loss: 1.0559 - val_categorical_accuracy: 0.5455
#
# Epoch 00001: val_loss improved from inf to 1.05593, saving model to modelo/inception_v3.h5
# Epoch 2/20
# 73/73 [==============================] - 2s 26ms/step - loss: 1.1395 - categorical_accuracy: 0.5481 - val_loss: 0.8828 - val_categorical_accuracy: 0.7013
#
# Epoch 00002: val_loss improved from 1.05593 to 0.88282, saving model to modelo/inception_v3.h5
# Epoch 3/20
# 73/73 [==============================] - 2s 25ms/step - loss: 1.0093 - categorical_accuracy: 0.6180 - val_loss: 0.7653 - val_categorical_accuracy: 0.7273
#
# Epoch 00003: val_loss improved from 0.88282 to 0.76526, saving model to modelo/inception_v3.h5
# Epoch 4/20
# 73/73 [==============================] - 2s 26ms/step - loss: 0.9026 - categorical_accuracy: 0.6706 - val_loss: 0.6910 - val_categorical_accuracy: 0.7403
#
# Epoch 00004: val_loss improved from 0.76526 to 0.69098, saving model to modelo/inception_v3.h5
# Epoch 5/20
# 73/73 [==============================] - 2s 25ms/step - loss: 0.8333 - categorical_accuracy: 0.6919 - val_loss: 0.6298 - val_categorical_accuracy: 0.8052
#
# Epoch 00005: val_loss improved from 0.69098 to 0.62983, saving model to modelo/inception_v3.h5
# Epoch 6/20
# 73/73 [==============================] - 2s 25ms/step - loss: 0.7836 - categorical_accuracy: 0.6939 - val_loss: 0.5817 - val_categorical_accuracy: 0.8312
#
# Epoch 00006: val_loss improved from 0.62983 to 0.58173, saving model to modelo/inception_v3.h5
# Epoch 7/20
# 73/73 [==============================] - 2s 25ms/step - loss: 0.7363 - categorical_accuracy: 0.7394 - val_loss: 0.5459 - val_categorical_accuracy: 0.8571
#
# Epoch 00007: val_loss improved from 0.58173 to 0.54592, saving model to modelo/inception_v3.h5
# Epoch 8/20
# 73/73 [==============================] - 2s 26ms/step - loss: 0.6916 - categorical_accuracy: 0.7375 - val_loss: 0.5134 - val_categorical_accuracy: 0.8571
#
# Epoch 00008: val_loss improved from 0.54592 to 0.51339, saving model to modelo/inception_v3.h5
# Epoch 9/20
# 73/73 [==============================] - 2s 25ms/step - loss: 0.5972 - categorical_accuracy: 0.8000 - val_loss: 0.4960 - val_categorical_accuracy: 0.8701
#
# Epoch 00009: val_loss improved from 0.51339 to 0.49598, saving model to modelo/inception_v3.h5
# Epoch 10/20
# 73/73 [==============================] - 2s 25ms/step - loss: 0.5712 - categorical_accuracy: 0.8118 - val_loss: 0.4755 - val_categorical_accuracy: 0.8831
#
# Epoch 00010: val_loss improved from 0.49598 to 0.47553, saving model to modelo/inception_v3.h5
# Epoch 11/20
# 73/73 [==============================] - 2s 25ms/step - loss: 0.5761 - categorical_accuracy: 0.8156 - val_loss: 0.4576 - val_categorical_accuracy: 0.8831
#
# Epoch 00011: val_loss improved from 0.47553 to 0.45759, saving model to modelo/inception_v3.h5
# Epoch 12/20
# 73/73 [==============================] - 2s 25ms/step - loss: 0.5123 - categorical_accuracy: 0.8486 - val_loss: 0.4406 - val_categorical_accuracy: 0.8831
#
# Epoch 00012: val_loss improved from 0.45759 to 0.44061, saving model to modelo/inception_v3.h5
# Epoch 13/20
# 73/73 [==============================] - 2s 25ms/step - loss: 0.5267 - categorical_accuracy: 0.8289 - val_loss: 0.4229 - val_categorical_accuracy: 0.8831
#
# Epoch 00013: val_loss improved from 0.44061 to 0.42287, saving model to modelo/inception_v3.h5
# Epoch 14/20
# 73/73 [==============================] - 2s 25ms/step - loss: 0.5320 - categorical_accuracy: 0.8209 - val_loss: 0.4135 - val_categorical_accuracy: 0.8701
#
# Epoch 00014: val_loss improved from 0.42287 to 0.41351, saving model to modelo/inception_v3.h5
# Epoch 15/20
# 73/73 [==============================] - 2s 25ms/step - loss: 0.5061 - categorical_accuracy: 0.8319 - val_loss: 0.4071 - val_categorical_accuracy: 0.8701
#
# Epoch 00015: val_loss improved from 0.41351 to 0.40708, saving model to modelo/inception_v3.h5
# Epoch 16/20
# 73/73 [==============================] - 2s 26ms/step - loss: 0.4957 - categorical_accuracy: 0.8288 - val_loss: 0.3881 - val_categorical_accuracy: 0.8831
#
# Epoch 00016: val_loss improved from 0.40708 to 0.38806, saving model to modelo/inception_v3.h5
# Epoch 17/20
# 73/73 [==============================] - 2s 25ms/step - loss: 0.5218 - categorical_accuracy: 0.8195 - val_loss: 0.3750 - val_categorical_accuracy: 0.8831
#
# Epoch 00017: val_loss improved from 0.38806 to 0.37495, saving model to modelo/inception_v3.h5
# Epoch 18/20
# 73/73 [==============================] - 2s 26ms/step - loss: 0.4912 - categorical_accuracy: 0.8583 - val_loss: 0.3791 - val_categorical_accuracy: 0.8831
#
# Epoch 00018: val_loss did not improve from 0.37495
# Epoch 19/20
# 73/73 [==============================] - 2s 25ms/step - loss: 0.4597 - categorical_accuracy: 0.8402 - val_loss: 0.3770 - val_categorical_accuracy: 0.8701
#
# Epoch 00019: val_loss did not improve from 0.37495
# Epoch 20/20
# 73/73 [==============================] - 2s 25ms/step - loss: 0.4479 - categorical_accuracy: 0.8455 - val_loss: 0.3697 - val_categorical_accuracy: 0.8831
#
# Epoch 00020: val_loss improved from 0.37495 to 0.36968, saving model to modelo/inception_v3.h5
# Epoch 21/30
# 73/73 [==============================] - 71s 495ms/step - loss: 0.4171 - categorical_accuracy: 0.8590 - val_loss: 0.1789 - val_categorical_accuracy: 0.9091
#
# Epoch 00021: val_loss improved from inf to 0.17890, saving model to modelo/inception_v3.h5
# Epoch 22/30
# 73/73 [==============================] - 4s 49ms/step - loss: 0.2037 - categorical_accuracy: 0.9368 - val_loss: 0.1999 - val_categorical_accuracy: 0.9221
#
# Epoch 00022: val_loss did not improve from 0.17890
# Epoch 23/30
# 73/73 [==============================] - 4s 49ms/step - loss: 0.1710 - categorical_accuracy: 0.9443 - val_loss: 0.1070 - val_categorical_accuracy: 0.9610
#
# Epoch 00023: val_loss improved from 0.17890 to 0.10696, saving model to modelo/inception_v3.h5
# Epoch 24/30
# 73/73 [==============================] - 4s 49ms/step - loss: 0.0850 - categorical_accuracy: 0.9715 - val_loss: 0.1349 - val_categorical_accuracy: 0.9481
#
# Epoch 00024: val_loss did not improve from 0.10696
# Epoch 25/30
# 73/73 [==============================] - 4s 49ms/step - loss: 0.0694 - categorical_accuracy: 0.9834 - val_loss: 0.2050 - val_categorical_accuracy: 0.9481
#
# Epoch 00025: val_loss did not improve from 0.10696
# Epoch 26/30
# 73/73 [==============================] - 4s 49ms/step - loss: 0.0512 - categorical_accuracy: 0.9924 - val_loss: 0.2037 - val_categorical_accuracy: 0.9351
#
# Epoch 00026: val_loss did not improve from 0.10696
# Epoch 27/30
# 73/73 [==============================] - 4s 49ms/step - loss: 0.0277 - categorical_accuracy: 0.9973 - val_loss: 0.1436 - val_categorical_accuracy: 0.9610
#
# Epoch 00027: val_loss did not improve from 0.10696
# Epoch 28/30
# 73/73 [==============================] - 4s 49ms/step - loss: 0.0279 - categorical_accuracy: 0.9920 - val_loss: 0.1431 - val_categorical_accuracy: 0.9481
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-07.
#
# Epoch 00028: val_loss did not improve from 0.10696
# Epoch 29/30
# 73/73 [==============================] - 4s 49ms/step - loss: 0.0099 - categorical_accuracy: 0.9961 - val_loss: 0.1416 - val_categorical_accuracy: 0.9481
#
# Epoch 00029: val_loss did not improve from 0.10696
# Epoch 30/30
# 73/73 [==============================] - 4s 49ms/step - loss: 0.0096 - categorical_accuracy: 1.0000 - val_loss: 0.1449 - val_categorical_accuracy: 0.9481
#
# Epoch 00030: val_loss did not improve from 0.10696
# 15/15 [==============================] - 36s 3s/step
# {'model': 'inception_v3', 'kappa': 0.8379714193617707, 'accuracy': 0.8879310344827587, 'recall': 0.8879310344827587, 'precision': 0.8952293121405374, 'f1': 0.8829632497303874, 'specificity': 0.9475845067274988, 'roc': 0.8934662265908567}
#
# Executando modelo xception
# Found 577 validated image filenames belonging to 4 classes.
# Found 77 validated image filenames belonging to 4 classes.
# Found 116 validated image filenames belonging to 4 classes.
# Epoch 1/20
# 73/73 [==============================] - 33s 303ms/step - loss: 1.2860 - categorical_accuracy: 0.3866 - val_loss: 1.0579 - val_categorical_accuracy: 0.7013
#
# Epoch 00001: val_loss improved from inf to 1.05794, saving model to modelo/xception.h5
# Epoch 2/20
# 73/73 [==============================] - 2s 32ms/step - loss: 1.1301 - categorical_accuracy: 0.6013 - val_loss: 0.9278 - val_categorical_accuracy: 0.7273
#
# Epoch 00002: val_loss improved from 1.05794 to 0.92782, saving model to modelo/xception.h5
# Epoch 3/20
# 73/73 [==============================] - 2s 32ms/step - loss: 0.9616 - categorical_accuracy: 0.6617 - val_loss: 0.8411 - val_categorical_accuracy: 0.7273
#
# Epoch 00003: val_loss improved from 0.92782 to 0.84108, saving model to modelo/xception.h5
# Epoch 4/20
# 73/73 [==============================] - 2s 32ms/step - loss: 0.8870 - categorical_accuracy: 0.7008 - val_loss: 0.7759 - val_categorical_accuracy: 0.7143
#
# Epoch 00004: val_loss improved from 0.84108 to 0.77591, saving model to modelo/xception.h5
# Epoch 5/20
# 73/73 [==============================] - 2s 32ms/step - loss: 0.7933 - categorical_accuracy: 0.7181 - val_loss: 0.7195 - val_categorical_accuracy: 0.7532
#
# Epoch 00005: val_loss improved from 0.77591 to 0.71950, saving model to modelo/xception.h5
# Epoch 6/20
# 73/73 [==============================] - 2s 32ms/step - loss: 0.7880 - categorical_accuracy: 0.7017 - val_loss: 0.6751 - val_categorical_accuracy: 0.7662
#
# Epoch 00006: val_loss improved from 0.71950 to 0.67514, saving model to modelo/xception.h5
# Epoch 7/20
# 73/73 [==============================] - 2s 32ms/step - loss: 0.7167 - categorical_accuracy: 0.7351 - val_loss: 0.6369 - val_categorical_accuracy: 0.7662
#
# Epoch 00007: val_loss improved from 0.67514 to 0.63687, saving model to modelo/xception.h5
# Epoch 8/20
# 73/73 [==============================] - 2s 32ms/step - loss: 0.6940 - categorical_accuracy: 0.7569 - val_loss: 0.6079 - val_categorical_accuracy: 0.7792
#
# Epoch 00008: val_loss improved from 0.63687 to 0.60792, saving model to modelo/xception.h5
# Epoch 9/20
# 73/73 [==============================] - 2s 32ms/step - loss: 0.7029 - categorical_accuracy: 0.7759 - val_loss: 0.5797 - val_categorical_accuracy: 0.8182
#
# Epoch 00009: val_loss improved from 0.60792 to 0.57975, saving model to modelo/xception.h5
# Epoch 10/20
# 73/73 [==============================] - 2s 32ms/step - loss: 0.6240 - categorical_accuracy: 0.7842 - val_loss: 0.5566 - val_categorical_accuracy: 0.8442
#
# Epoch 00010: val_loss improved from 0.57975 to 0.55658, saving model to modelo/xception.h5
# Epoch 11/20
# 73/73 [==============================] - 2s 32ms/step - loss: 0.6273 - categorical_accuracy: 0.7910 - val_loss: 0.5353 - val_categorical_accuracy: 0.8571
#
# Epoch 00011: val_loss improved from 0.55658 to 0.53532, saving model to modelo/xception.h5
# Epoch 12/20
# 73/73 [==============================] - 2s 32ms/step - loss: 0.6463 - categorical_accuracy: 0.7736 - val_loss: 0.5183 - val_categorical_accuracy: 0.8701
#
# Epoch 00012: val_loss improved from 0.53532 to 0.51829, saving model to modelo/xception.h5
# Epoch 13/20
# 73/73 [==============================] - 2s 32ms/step - loss: 0.5640 - categorical_accuracy: 0.8168 - val_loss: 0.5005 - val_categorical_accuracy: 0.8701
#
# Epoch 00013: val_loss improved from 0.51829 to 0.50048, saving model to modelo/xception.h5
# Epoch 14/20
# 73/73 [==============================] - 2s 32ms/step - loss: 0.6216 - categorical_accuracy: 0.7930 - val_loss: 0.4856 - val_categorical_accuracy: 0.8831
#
# Epoch 00014: val_loss improved from 0.50048 to 0.48559, saving model to modelo/xception.h5
# Epoch 15/20
# 73/73 [==============================] - 2s 32ms/step - loss: 0.5368 - categorical_accuracy: 0.8292 - val_loss: 0.4709 - val_categorical_accuracy: 0.8831
#
# Epoch 00015: val_loss improved from 0.48559 to 0.47092, saving model to modelo/xception.h5
# Epoch 16/20
# 73/73 [==============================] - 2s 32ms/step - loss: 0.5300 - categorical_accuracy: 0.8458 - val_loss: 0.4612 - val_categorical_accuracy: 0.8831
#
# Epoch 00016: val_loss improved from 0.47092 to 0.46117, saving model to modelo/xception.h5
# Epoch 17/20
# 73/73 [==============================] - 2s 32ms/step - loss: 0.5365 - categorical_accuracy: 0.8155 - val_loss: 0.4470 - val_categorical_accuracy: 0.8961
#
# Epoch 00017: val_loss improved from 0.46117 to 0.44700, saving model to modelo/xception.h5
# Epoch 18/20
# 73/73 [==============================] - 2s 32ms/step - loss: 0.4989 - categorical_accuracy: 0.8316 - val_loss: 0.4410 - val_categorical_accuracy: 0.8961
#
# Epoch 00018: val_loss improved from 0.44700 to 0.44102, saving model to modelo/xception.h5
# Epoch 19/20
# 73/73 [==============================] - 2s 32ms/step - loss: 0.4997 - categorical_accuracy: 0.8742 - val_loss: 0.4296 - val_categorical_accuracy: 0.8831
#
# Epoch 00019: val_loss improved from 0.44102 to 0.42961, saving model to modelo/xception.h5
# Epoch 20/20
# 73/73 [==============================] - 2s 32ms/step - loss: 0.4948 - categorical_accuracy: 0.8390 - val_loss: 0.4162 - val_categorical_accuracy: 0.8961
#
# Epoch 00020: val_loss improved from 0.42961 to 0.41621, saving model to modelo/xception.h5
# Epoch 21/30
# 73/73 [==============================] - 16s 121ms/step - loss: 0.4732 - categorical_accuracy: 0.8386 - val_loss: 0.2936 - val_categorical_accuracy: 0.9091
#
# Epoch 00021: val_loss improved from inf to 0.29360, saving model to modelo/xception.h5
# Epoch 22/30
# 73/73 [==============================] - 3s 44ms/step - loss: 0.3771 - categorical_accuracy: 0.8678 - val_loss: 0.2820 - val_categorical_accuracy: 0.9221
#
# Epoch 00022: val_loss improved from 0.29360 to 0.28200, saving model to modelo/xception.h5
# Epoch 23/30
# 73/73 [==============================] - 3s 44ms/step - loss: 0.2875 - categorical_accuracy: 0.8972 - val_loss: 0.2622 - val_categorical_accuracy: 0.9221
#
# Epoch 00023: val_loss improved from 0.28200 to 0.26224, saving model to modelo/xception.h5
# Epoch 24/30
# 73/73 [==============================] - 3s 44ms/step - loss: 0.2338 - categorical_accuracy: 0.9153 - val_loss: 0.2643 - val_categorical_accuracy: 0.9221
#
# Epoch 00024: val_loss did not improve from 0.26224
# Epoch 25/30
# 73/73 [==============================] - 3s 44ms/step - loss: 0.2210 - categorical_accuracy: 0.9336 - val_loss: 0.2207 - val_categorical_accuracy: 0.9351
#
# Epoch 00025: val_loss improved from 0.26224 to 0.22070, saving model to modelo/xception.h5
# Epoch 26/30
# 73/73 [==============================] - 3s 44ms/step - loss: 0.1426 - categorical_accuracy: 0.9589 - val_loss: 0.2076 - val_categorical_accuracy: 0.9351
#
# Epoch 00026: val_loss improved from 0.22070 to 0.20764, saving model to modelo/xception.h5
# Epoch 27/30
# 73/73 [==============================] - 3s 44ms/step - loss: 0.1286 - categorical_accuracy: 0.9772 - val_loss: 0.2167 - val_categorical_accuracy: 0.9351
#
# Epoch 00027: val_loss did not improve from 0.20764
# Epoch 28/30
# 73/73 [==============================] - 3s 44ms/step - loss: 0.1125 - categorical_accuracy: 0.9635 - val_loss: 0.2367 - val_categorical_accuracy: 0.9221
#
# Epoch 00028: val_loss did not improve from 0.20764
# Epoch 29/30
# 73/73 [==============================] - 3s 44ms/step - loss: 0.0768 - categorical_accuracy: 0.9784 - val_loss: 0.2064 - val_categorical_accuracy: 0.9351
#
# Epoch 00029: val_loss improved from 0.20764 to 0.20637, saving model to modelo/xception.h5
# Epoch 30/30
# 73/73 [==============================] - 3s 45ms/step - loss: 0.0557 - categorical_accuracy: 0.9827 - val_loss: 0.1914 - val_categorical_accuracy: 0.9351
#
# Epoch 00030: val_loss improved from 0.20637 to 0.19135, saving model to modelo/xception.h5
# 15/15 [==============================] - 11s 722ms/step
# {'model': 'xception', 'kappa': 0.8516307823491793, 'accuracy': 0.896551724137931, 'recall': 0.896551724137931, 'precision': 0.899265751739515, 'f1': 0.8927435712883597, 'specificity': 0.959144008700659, 'roc': 0.9038012505443984}
#
# Executando modelo inception_resnet_v2
# Found 577 validated image filenames belonging to 4 classes.
# Found 77 validated image filenames belonging to 4 classes.
# Found 116 validated image filenames belonging to 4 classes.
# Epoch 1/20
# 73/73 [==============================] - 74s 643ms/step - loss: 1.4998 - categorical_accuracy: 0.3468 - val_loss: 1.0626 - val_categorical_accuracy: 0.5714
#
# Epoch 00001: val_loss improved from inf to 1.06260, saving model to modelo/inception_resnet_v2.h5
# Epoch 2/20
# 73/73 [==============================] - 4s 53ms/step - loss: 1.0866 - categorical_accuracy: 0.5794 - val_loss: 0.8904 - val_categorical_accuracy: 0.7013
#
# Epoch 00002: val_loss improved from 1.06260 to 0.89042, saving model to modelo/inception_resnet_v2.h5
# Epoch 3/20
# 73/73 [==============================] - 4s 53ms/step - loss: 1.0028 - categorical_accuracy: 0.6166 - val_loss: 0.7972 - val_categorical_accuracy: 0.6883
#
# Epoch 00003: val_loss improved from 0.89042 to 0.79723, saving model to modelo/inception_resnet_v2.h5
# Epoch 4/20
# 73/73 [==============================] - 4s 52ms/step - loss: 0.8808 - categorical_accuracy: 0.6902 - val_loss: 0.7134 - val_categorical_accuracy: 0.7143
#
# Epoch 00004: val_loss improved from 0.79723 to 0.71337, saving model to modelo/inception_resnet_v2.h5
# Epoch 5/20
# 73/73 [==============================] - 4s 53ms/step - loss: 0.8716 - categorical_accuracy: 0.6865 - val_loss: 0.6511 - val_categorical_accuracy: 0.7532
#
# Epoch 00005: val_loss improved from 0.71337 to 0.65106, saving model to modelo/inception_resnet_v2.h5
# Epoch 6/20
# 73/73 [==============================] - 4s 53ms/step - loss: 0.8018 - categorical_accuracy: 0.7028 - val_loss: 0.6115 - val_categorical_accuracy: 0.7662
#
# Epoch 00006: val_loss improved from 0.65106 to 0.61152, saving model to modelo/inception_resnet_v2.h5
# Epoch 7/20
# 73/73 [==============================] - 4s 53ms/step - loss: 0.6860 - categorical_accuracy: 0.7513 - val_loss: 0.5785 - val_categorical_accuracy: 0.8052
#
# Epoch 00007: val_loss improved from 0.61152 to 0.57849, saving model to modelo/inception_resnet_v2.h5
# Epoch 8/20
# 73/73 [==============================] - 4s 53ms/step - loss: 0.6770 - categorical_accuracy: 0.7573 - val_loss: 0.5561 - val_categorical_accuracy: 0.8052
#
# Epoch 00008: val_loss improved from 0.57849 to 0.55612, saving model to modelo/inception_resnet_v2.h5
# Epoch 9/20
# 73/73 [==============================] - 4s 53ms/step - loss: 0.6615 - categorical_accuracy: 0.7670 - val_loss: 0.5267 - val_categorical_accuracy: 0.8442
#
# Epoch 00009: val_loss improved from 0.55612 to 0.52672, saving model to modelo/inception_resnet_v2.h5
# Epoch 10/20
# 73/73 [==============================] - 4s 53ms/step - loss: 0.6430 - categorical_accuracy: 0.7739 - val_loss: 0.5029 - val_categorical_accuracy: 0.8052
#
# Epoch 00010: val_loss improved from 0.52672 to 0.50288, saving model to modelo/inception_resnet_v2.h5
# Epoch 11/20
# 73/73 [==============================] - 4s 53ms/step - loss: 0.6444 - categorical_accuracy: 0.7418 - val_loss: 0.4924 - val_categorical_accuracy: 0.8571
#
# Epoch 00011: val_loss improved from 0.50288 to 0.49238, saving model to modelo/inception_resnet_v2.h5
# Epoch 12/20
# 73/73 [==============================] - 4s 53ms/step - loss: 0.6021 - categorical_accuracy: 0.8104 - val_loss: 0.4653 - val_categorical_accuracy: 0.8442
#
# Epoch 00012: val_loss improved from 0.49238 to 0.46530, saving model to modelo/inception_resnet_v2.h5
# Epoch 13/20
# 73/73 [==============================] - 4s 53ms/step - loss: 0.5990 - categorical_accuracy: 0.7712 - val_loss: 0.4583 - val_categorical_accuracy: 0.8701
#
# Epoch 00013: val_loss improved from 0.46530 to 0.45834, saving model to modelo/inception_resnet_v2.h5
# Epoch 14/20
# 73/73 [==============================] - 4s 53ms/step - loss: 0.5412 - categorical_accuracy: 0.8227 - val_loss: 0.4456 - val_categorical_accuracy: 0.8831
#
# Epoch 00014: val_loss improved from 0.45834 to 0.44563, saving model to modelo/inception_resnet_v2.h5
# Epoch 15/20
# 73/73 [==============================] - 4s 53ms/step - loss: 0.5402 - categorical_accuracy: 0.8154 - val_loss: 0.4323 - val_categorical_accuracy: 0.8701
#
# Epoch 00015: val_loss improved from 0.44563 to 0.43233, saving model to modelo/inception_resnet_v2.h5
# Epoch 16/20
# 73/73 [==============================] - 4s 53ms/step - loss: 0.5137 - categorical_accuracy: 0.8241 - val_loss: 0.4205 - val_categorical_accuracy: 0.8831
#
# Epoch 00016: val_loss improved from 0.43233 to 0.42054, saving model to modelo/inception_resnet_v2.h5
# Epoch 17/20
# 73/73 [==============================] - 4s 53ms/step - loss: 0.5791 - categorical_accuracy: 0.7892 - val_loss: 0.4076 - val_categorical_accuracy: 0.8701
#
# Epoch 00017: val_loss improved from 0.42054 to 0.40756, saving model to modelo/inception_resnet_v2.h5
# Epoch 18/20
# 73/73 [==============================] - 4s 53ms/step - loss: 0.5035 - categorical_accuracy: 0.8217 - val_loss: 0.4017 - val_categorical_accuracy: 0.8961
#
# Epoch 00018: val_loss improved from 0.40756 to 0.40167, saving model to modelo/inception_resnet_v2.h5
# Epoch 19/20
# 73/73 [==============================] - 4s 53ms/step - loss: 0.5031 - categorical_accuracy: 0.8315 - val_loss: 0.3937 - val_categorical_accuracy: 0.8961
#
# Epoch 00019: val_loss improved from 0.40167 to 0.39370, saving model to modelo/inception_resnet_v2.h5
# Epoch 20/20
# 73/73 [==============================] - 4s 54ms/step - loss: 0.5038 - categorical_accuracy: 0.8320 - val_loss: 0.3833 - val_categorical_accuracy: 0.8961
#
# Epoch 00020: val_loss improved from 0.39370 to 0.38335, saving model to modelo/inception_resnet_v2.h5
# Epoch 21/30
# 73/73 [==============================] - 85s 601ms/step - loss: 0.4443 - categorical_accuracy: 0.8667 - val_loss: 0.2391 - val_categorical_accuracy: 0.9221
#
# Epoch 00021: val_loss improved from inf to 0.23910, saving model to modelo/inception_resnet_v2.h5
# Epoch 22/30
# 73/73 [==============================] - 10s 137ms/step - loss: 0.2549 - categorical_accuracy: 0.9203 - val_loss: 0.1942 - val_categorical_accuracy: 0.9481
#
# Epoch 00022: val_loss improved from 0.23910 to 0.19424, saving model to modelo/inception_resnet_v2.h5
# Epoch 23/30
# 73/73 [==============================] - 10s 137ms/step - loss: 0.1273 - categorical_accuracy: 0.9641 - val_loss: 0.1705 - val_categorical_accuracy: 0.9351
#
# Epoch 00023: val_loss improved from 0.19424 to 0.17046, saving model to modelo/inception_resnet_v2.h5
# Epoch 24/30
# 73/73 [==============================] - 10s 136ms/step - loss: 0.1205 - categorical_accuracy: 0.9607 - val_loss: 0.1945 - val_categorical_accuracy: 0.9610
#
# Epoch 00024: val_loss did not improve from 0.17046
# Epoch 25/30
# 73/73 [==============================] - 10s 137ms/step - loss: 0.0517 - categorical_accuracy: 0.9852 - val_loss: 0.2189 - val_categorical_accuracy: 0.9351
#
# Epoch 00025: val_loss did not improve from 0.17046
# Epoch 26/30
# 73/73 [==============================] - 10s 137ms/step - loss: 0.0416 - categorical_accuracy: 0.9902 - val_loss: 0.2170 - val_categorical_accuracy: 0.9351
#
# Epoch 00026: val_loss did not improve from 0.17046
# Epoch 27/30
# 73/73 [==============================] - 10s 137ms/step - loss: 0.0253 - categorical_accuracy: 0.9927 - val_loss: 0.2180 - val_categorical_accuracy: 0.9351
#
# Epoch 00027: val_loss did not improve from 0.17046
# Epoch 28/30
# 73/73 [==============================] - 10s 138ms/step - loss: 0.0244 - categorical_accuracy: 0.9970 - val_loss: 0.1612 - val_categorical_accuracy: 0.9481
#
# Epoch 00028: val_loss improved from 0.17046 to 0.16116, saving model to modelo/inception_resnet_v2.h5
# Epoch 29/30
# 73/73 [==============================] - 10s 138ms/step - loss: 0.0210 - categorical_accuracy: 0.9879 - val_loss: 0.2173 - val_categorical_accuracy: 0.9481
#
# Epoch 00029: val_loss did not improve from 0.16116
# Epoch 30/30
# 73/73 [==============================] - 10s 139ms/step - loss: 0.0202 - categorical_accuracy: 0.9883 - val_loss: 0.1839 - val_categorical_accuracy: 0.9481
#
# Epoch 00030: val_loss did not improve from 0.16116
# 15/15 [==============================] - 23s 1s/step
# {'model': 'inception_resnet_v2', 'kappa': 0.8514090520922288, 'accuracy': 0.896551724137931, 'recall': 0.896551724137931, 'precision': 0.9026253918495297, 'f1': 0.8955722569531517, 'specificity': 0.9517467484266864, 'roc': 0.9094871699332288}
#
# Executando modelo NASNet
# Found 577 validated image filenames belonging to 4 classes.
# Found 77 validated image filenames belonging to 4 classes.
# Found 116 validated image filenames belonging to 4 classes.
# Epoch 1/20
# 73/73 [==============================] - 69s 608ms/step - loss: 1.3041 - categorical_accuracy: 0.4184 - val_loss: 0.9106 - val_categorical_accuracy: 0.6753
#
# Epoch 00001: val_loss improved from inf to 0.91060, saving model to modelo/NASNet.h5
# Epoch 2/20
# 73/73 [==============================] - 8s 109ms/step - loss: 0.9971 - categorical_accuracy: 0.6487 - val_loss: 0.7337 - val_categorical_accuracy: 0.7403
#
# Epoch 00002: val_loss improved from 0.91060 to 0.73373, saving model to modelo/NASNet.h5
# Epoch 3/20
# 73/73 [==============================] - 8s 109ms/step - loss: 0.8008 - categorical_accuracy: 0.6932 - val_loss: 0.6232 - val_categorical_accuracy: 0.7792
#
# Epoch 00003: val_loss improved from 0.73373 to 0.62321, saving model to modelo/NASNet.h5
# Epoch 4/20
# 73/73 [==============================] - 8s 109ms/step - loss: 0.7364 - categorical_accuracy: 0.7187 - val_loss: 0.5563 - val_categorical_accuracy: 0.8442
#
# Epoch 00004: val_loss improved from 0.62321 to 0.55626, saving model to modelo/NASNet.h5
# Epoch 5/20
# 73/73 [==============================] - 8s 110ms/step - loss: 0.6521 - categorical_accuracy: 0.7840 - val_loss: 0.5061 - val_categorical_accuracy: 0.8701
#
# Epoch 00005: val_loss improved from 0.55626 to 0.50614, saving model to modelo/NASNet.h5
# Epoch 6/20
# 73/73 [==============================] - 8s 110ms/step - loss: 0.5916 - categorical_accuracy: 0.7862 - val_loss: 0.4680 - val_categorical_accuracy: 0.8831
#
# Epoch 00006: val_loss improved from 0.50614 to 0.46795, saving model to modelo/NASNet.h5
# Epoch 7/20
# 73/73 [==============================] - 8s 109ms/step - loss: 0.5594 - categorical_accuracy: 0.8060 - val_loss: 0.4332 - val_categorical_accuracy: 0.8831
#
# Epoch 00007: val_loss improved from 0.46795 to 0.43322, saving model to modelo/NASNet.h5
# Epoch 8/20
# 73/73 [==============================] - 8s 110ms/step - loss: 0.5069 - categorical_accuracy: 0.8399 - val_loss: 0.4142 - val_categorical_accuracy: 0.8961
#
# Epoch 00008: val_loss improved from 0.43322 to 0.41419, saving model to modelo/NASNet.h5
# Epoch 9/20
# 73/73 [==============================] - 8s 109ms/step - loss: 0.4908 - categorical_accuracy: 0.8296 - val_loss: 0.3915 - val_categorical_accuracy: 0.8961
#
# Epoch 00009: val_loss improved from 0.41419 to 0.39148, saving model to modelo/NASNet.h5
# Epoch 10/20
# 73/73 [==============================] - 8s 110ms/step - loss: 0.5367 - categorical_accuracy: 0.7965 - val_loss: 0.3750 - val_categorical_accuracy: 0.8961
#
# Epoch 00010: val_loss improved from 0.39148 to 0.37496, saving model to modelo/NASNet.h5
# Epoch 11/20
# 73/73 [==============================] - 8s 110ms/step - loss: 0.4664 - categorical_accuracy: 0.8536 - val_loss: 0.3624 - val_categorical_accuracy: 0.8961
#
# Epoch 00011: val_loss improved from 0.37496 to 0.36245, saving model to modelo/NASNet.h5
# Epoch 12/20
# 73/73 [==============================] - 8s 110ms/step - loss: 0.4646 - categorical_accuracy: 0.8427 - val_loss: 0.3486 - val_categorical_accuracy: 0.9091
#
# Epoch 00012: val_loss improved from 0.36245 to 0.34859, saving model to modelo/NASNet.h5
# Epoch 13/20
# 73/73 [==============================] - 8s 110ms/step - loss: 0.4247 - categorical_accuracy: 0.8675 - val_loss: 0.3358 - val_categorical_accuracy: 0.8961
#
# Epoch 00013: val_loss improved from 0.34859 to 0.33578, saving model to modelo/NASNet.h5
# Epoch 14/20
# 73/73 [==============================] - 8s 110ms/step - loss: 0.4438 - categorical_accuracy: 0.8651 - val_loss: 0.3283 - val_categorical_accuracy: 0.8961
#
# Epoch 00014: val_loss improved from 0.33578 to 0.32829, saving model to modelo/NASNet.h5
# Epoch 15/20
# 73/73 [==============================] - 8s 110ms/step - loss: 0.4286 - categorical_accuracy: 0.8654 - val_loss: 0.3224 - val_categorical_accuracy: 0.8961
#
# Epoch 00015: val_loss improved from 0.32829 to 0.32243, saving model to modelo/NASNet.h5
# Epoch 16/20
# 73/73 [==============================] - 8s 111ms/step - loss: 0.3743 - categorical_accuracy: 0.9052 - val_loss: 0.3116 - val_categorical_accuracy: 0.8961
#
# Epoch 00016: val_loss improved from 0.32243 to 0.31158, saving model to modelo/NASNet.h5
# Epoch 17/20
# 73/73 [==============================] - 8s 110ms/step - loss: 0.3909 - categorical_accuracy: 0.8449 - val_loss: 0.3027 - val_categorical_accuracy: 0.9091
#
# Epoch 00017: val_loss improved from 0.31158 to 0.30265, saving model to modelo/NASNet.h5
# Epoch 18/20
# 73/73 [==============================] - 8s 111ms/step - loss: 0.3342 - categorical_accuracy: 0.9065 - val_loss: 0.2956 - val_categorical_accuracy: 0.9091
#
# Epoch 00018: val_loss improved from 0.30265 to 0.29563, saving model to modelo/NASNet.h5
# Epoch 19/20
# 73/73 [==============================] - 8s 111ms/step - loss: 0.3436 - categorical_accuracy: 0.8976 - val_loss: 0.2878 - val_categorical_accuracy: 0.9091
#
# Epoch 00019: val_loss improved from 0.29563 to 0.28781, saving model to modelo/NASNet.h5
# Epoch 20/20
# 73/73 [==============================] - 8s 111ms/step - loss: 0.3777 - categorical_accuracy: 0.8906 - val_loss: 0.2824 - val_categorical_accuracy: 0.9091
#
# Epoch 00020: val_loss improved from 0.28781 to 0.28235, saving model to modelo/NASNet.h5
# Epoch 21/30
# 73/73 [==============================] - 91s 730ms/step - loss: 0.3472 - categorical_accuracy: 0.8878 - val_loss: 0.1959 - val_categorical_accuracy: 0.9351
#
# Epoch 00021: val_loss improved from inf to 0.19588, saving model to modelo/NASNet.h5
# Epoch 22/30
# 73/73 [==============================] - 31s 426ms/step - loss: 0.1217 - categorical_accuracy: 0.9821 - val_loss: 0.1760 - val_categorical_accuracy: 0.9351
#
# Epoch 00022: val_loss improved from 0.19588 to 0.17599, saving model to modelo/NASNet.h5
# Epoch 23/30
# 73/73 [==============================] - 32s 439ms/step - loss: 0.0822 - categorical_accuracy: 0.9772 - val_loss: 0.1750 - val_categorical_accuracy: 0.9351
#
# Epoch 00023: val_loss improved from 0.17599 to 0.17504, saving model to modelo/NASNet.h5
# Epoch 24/30
# 73/73 [==============================] - 32s 441ms/step - loss: 0.0618 - categorical_accuracy: 0.9889 - val_loss: 0.1835 - val_categorical_accuracy: 0.9351
#
# Epoch 00024: val_loss did not improve from 0.17504
# Epoch 25/30
# 73/73 [==============================] - 32s 445ms/step - loss: 0.0276 - categorical_accuracy: 0.9972 - val_loss: 0.1991 - val_categorical_accuracy: 0.9221
#
# Epoch 00025: val_loss did not improve from 0.17504
# Epoch 26/30
# 73/73 [==============================] - 32s 444ms/step - loss: 0.0130 - categorical_accuracy: 0.9983 - val_loss: 0.1959 - val_categorical_accuracy: 0.9221
#
# Epoch 00026: val_loss did not improve from 0.17504
# Epoch 27/30
# 73/73 [==============================] - 33s 446ms/step - loss: 0.0051 - categorical_accuracy: 1.0000 - val_loss: 0.2159 - val_categorical_accuracy: 0.9351
#
# Epoch 00027: val_loss did not improve from 0.17504
# Epoch 28/30
# 73/73 [==============================] - 33s 445ms/step - loss: 0.0051 - categorical_accuracy: 1.0000 - val_loss: 0.2263 - val_categorical_accuracy: 0.9221
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-07.
#
# Epoch 00028: val_loss did not improve from 0.17504
# Epoch 29/30
# ...
# {'model': 'inception_resnet_v2', 'kappa': 1.0, 'accuracy': 1.0, 'recall': 1.0, 'precision': 1.0, 'f1': 1.0, 'specificity': 1.0, 'roc': 1.0}
#
# Executando modelo NASNet
# Found 579 validated image filenames belonging to 4 classes.
# Found 76 validated image filenames belonging to 4 classes.
# Found 115 validated image filenames belonging to 4 classes.
# Epoch 1/20
# 73/73 [==============================] - 38s 385ms/step - loss: 1.3197 - categorical_accuracy: 0.4008 - val_loss: 0.3470 - val_categorical_accuracy: 0.9079
#
# Epoch 00001: val_loss improved from inf to 0.34702, saving model to modelo/NASNet.h5
# Epoch 2/20
# 73/73 [==============================] - 8s 109ms/step - loss: 0.3205 - categorical_accuracy: 0.9241 - val_loss: 0.1985 - val_categorical_accuracy: 0.9474
#
# Epoch 00002: val_loss improved from 0.34702 to 0.19853, saving model to modelo/NASNet.h5
# Epoch 3/20
# 73/73 [==============================] - 8s 109ms/step - loss: 0.1995 - categorical_accuracy: 0.9654 - val_loss: 0.1182 - val_categorical_accuracy: 0.9737
#
# Epoch 00003: val_loss improved from 0.19853 to 0.11817, saving model to modelo/NASNet.h5
# Epoch 4/20
# 73/73 [==============================] - 8s 109ms/step - loss: 0.1326 - categorical_accuracy: 0.9682 - val_loss: 0.0877 - val_categorical_accuracy: 0.9868
#
# Epoch 00004: val_loss improved from 0.11817 to 0.08771, saving model to modelo/NASNet.h5
# Epoch 5/20
# 73/73 [==============================] - 8s 109ms/step - loss: 0.1206 - categorical_accuracy: 0.9649 - val_loss: 0.0683 - val_categorical_accuracy: 0.9868
#
# Epoch 00005: val_loss improved from 0.08771 to 0.06828, saving model to modelo/NASNet.h5
# Epoch 6/20
# 73/73 [==============================] - 8s 109ms/step - loss: 0.0803 - categorical_accuracy: 0.9816 - val_loss: 0.0549 - val_categorical_accuracy: 0.9868
#
# Epoch 00006: val_loss improved from 0.06828 to 0.05490, saving model to modelo/NASNet.h5
# Epoch 7/20
# 73/73 [==============================] - 8s 110ms/step - loss: 0.0937 - categorical_accuracy: 0.9748 - val_loss: 0.0444 - val_categorical_accuracy: 0.9868
#
# Epoch 00007: val_loss improved from 0.05490 to 0.04435, saving model to modelo/NASNet.h5
# Epoch 8/20
# 73/73 [==============================] - 8s 109ms/step - loss: 0.0592 - categorical_accuracy: 0.9927 - val_loss: 0.0387 - val_categorical_accuracy: 1.0000
#
# Epoch 00008: val_loss improved from 0.04435 to 0.03872, saving model to modelo/NASNet.h5
# Epoch 9/20
# 73/73 [==============================] - 8s 109ms/step - loss: 0.0521 - categorical_accuracy: 0.9903 - val_loss: 0.0332 - val_categorical_accuracy: 1.0000
#
# Epoch 00009: val_loss improved from 0.03872 to 0.03323, saving model to modelo/NASNet.h5
# Epoch 10/20
# 73/73 [==============================] - 8s 110ms/step - loss: 0.0504 - categorical_accuracy: 0.9882 - val_loss: 0.0309 - val_categorical_accuracy: 1.0000
#
# Epoch 00010: val_loss improved from 0.03323 to 0.03087, saving model to modelo/NASNet.h5
# Epoch 11/20
# 73/73 [==============================] - 8s 109ms/step - loss: 0.0601 - categorical_accuracy: 0.9825 - val_loss: 0.0261 - val_categorical_accuracy: 1.0000
#
# Epoch 00011: val_loss improved from 0.03087 to 0.02607, saving model to modelo/NASNet.h5
# Epoch 12/20
# 73/73 [==============================] - 8s 110ms/step - loss: 0.0495 - categorical_accuracy: 0.9937 - val_loss: 0.0230 - val_categorical_accuracy: 1.0000
#
# Epoch 00012: val_loss improved from 0.02607 to 0.02297, saving model to modelo/NASNet.h5
# Epoch 13/20
# 73/73 [==============================] - 8s 110ms/step - loss: 0.0228 - categorical_accuracy: 0.9968 - val_loss: 0.0260 - val_categorical_accuracy: 1.0000
#
# Epoch 00013: val_loss did not improve from 0.02297
# Epoch 14/20
# 73/73 [==============================] - 8s 110ms/step - loss: 0.0248 - categorical_accuracy: 0.9985 - val_loss: 0.0188 - val_categorical_accuracy: 1.0000
#
# Epoch 00014: val_loss improved from 0.02297 to 0.01876, saving model to modelo/NASNet.h5
# Epoch 15/20
# 73/73 [==============================] - 8s 110ms/step - loss: 0.0268 - categorical_accuracy: 0.9953 - val_loss: 0.0203 - val_categorical_accuracy: 1.0000
#
# Epoch 00015: val_loss did not improve from 0.01876
# Epoch 16/20
# 73/73 [==============================] - 8s 111ms/step - loss: 0.0257 - categorical_accuracy: 0.9982 - val_loss: 0.0186 - val_categorical_accuracy: 1.0000
#
# Epoch 00016: val_loss improved from 0.01876 to 0.01860, saving model to modelo/NASNet.h5
# Epoch 17/20
# 73/73 [==============================] - 8s 110ms/step - loss: 0.0318 - categorical_accuracy: 0.9932 - val_loss: 0.0180 - val_categorical_accuracy: 1.0000
#
# Epoch 00017: val_loss improved from 0.01860 to 0.01801, saving model to modelo/NASNet.h5
# Epoch 18/20
# 73/73 [==============================] - 8s 110ms/step - loss: 0.0208 - categorical_accuracy: 0.9951 - val_loss: 0.0169 - val_categorical_accuracy: 1.0000
#
# Epoch 00018: val_loss improved from 0.01801 to 0.01693, saving model to modelo/NASNet.h5
# Epoch 19/20
# 73/73 [==============================] - 8s 110ms/step - loss: 0.0317 - categorical_accuracy: 0.9908 - val_loss: 0.0144 - val_categorical_accuracy: 1.0000
#
# Epoch 00019: val_loss improved from 0.01693 to 0.01444, saving model to modelo/NASNet.h5
# Epoch 20/20
# 73/73 [==============================] - 8s 110ms/step - loss: 0.0217 - categorical_accuracy: 0.9949 - val_loss: 0.0172 - val_categorical_accuracy: 1.0000
#
# Epoch 00020: val_loss did not improve from 0.01444
# Epoch 21/30
# 73/73 [==============================] - 74s 741ms/step - loss: 0.0449 - categorical_accuracy: 0.9854 - val_loss: 0.0351 - val_categorical_accuracy: 0.9868
#
# Epoch 00021: val_loss improved from inf to 0.03505, saving model to modelo/NASNet.h5
# Epoch 22/30
# 73/73 [==============================] - 33s 458ms/step - loss: 0.0155 - categorical_accuracy: 0.9978 - val_loss: 0.0342 - val_categorical_accuracy: 0.9868
#
# Epoch 00022: val_loss improved from 0.03505 to 0.03415, saving model to modelo/NASNet.h5
# Epoch 23/30
# 73/73 [==============================] - 34s 461ms/step - loss: 0.0281 - categorical_accuracy: 0.9912 - val_loss: 0.0160 - val_categorical_accuracy: 0.9868
#
# Epoch 00023: val_loss improved from 0.03415 to 0.01602, saving model to modelo/NASNet.h5
# Epoch 24/30
# 73/73 [==============================] - 34s 465ms/step - loss: 0.0082 - categorical_accuracy: 0.9990 - val_loss: 0.0160 - val_categorical_accuracy: 0.9868
#
# Epoch 00024: val_loss improved from 0.01602 to 0.01601, saving model to modelo/NASNet.h5
# Epoch 25/30
# 73/73 [==============================] - 34s 466ms/step - loss: 0.0125 - categorical_accuracy: 0.9973 - val_loss: 0.0182 - val_categorical_accuracy: 0.9868
#
# Epoch 00025: val_loss did not improve from 0.01601
# Epoch 26/30
# 73/73 [==============================] - 34s 468ms/step - loss: 0.0024 - categorical_accuracy: 1.0000 - val_loss: 0.0124 - val_categorical_accuracy: 0.9868
#
# Epoch 00026: val_loss improved from 0.01601 to 0.01241, saving model to modelo/NASNet.h5
# Epoch 27/30
# 73/73 [==============================] - 34s 467ms/step - loss: 8.9154e-04 - categorical_accuracy: 1.0000 - val_loss: 0.0138 - val_categorical_accuracy: 0.9868
#
# Epoch 00027: val_loss did not improve from 0.01241
# Epoch 28/30
# 73/73 [==============================] - 34s 469ms/step - loss: 0.0057 - categorical_accuracy: 0.9976 - val_loss: 0.0154 - val_categorical_accuracy: 0.9868
#
# Epoch 00028: val_loss did not improve from 0.01241
# Epoch 29/30
# 73/73 [==============================] - 34s 471ms/step - loss: 7.9105e-04 - categorical_accuracy: 1.0000 - val_loss: 0.0193 - val_categorical_accuracy: 0.9868
#
# Epoch 00029: val_loss did not improve from 0.01241
# Epoch 30/30
# 73/73 [==============================] - 34s 471ms/step - loss: 0.0018 - categorical_accuracy: 1.0000 - val_loss: 0.0195 - val_categorical_accuracy: 0.9868
#
# Epoch 00030: val_loss did not improve from 0.01241
# 15/15 [==============================] - 5s 92ms/step
# {'model': 'NASNet', 'kappa': 1.0, 'accuracy': 1.0, 'recall': 1.0, 'precision': 1.0, 'f1': 1.0, 'specificity': 1.0, 'roc': 1.0}
#
# Executando modelo resnet152v2
# Found 579 validated image filenames belonging to 4 classes.
# Found 76 validated image filenames belonging to 4 classes.
# Found 115 validated image filenames belonging to 4 classes.
# Epoch 1/20
# 73/73 [==============================] - 33s 391ms/step - loss: 2.6775 - categorical_accuracy: 0.2864 - val_loss: 0.5857 - val_categorical_accuracy: 0.7763
#
# Epoch 00001: val_loss improved from inf to 0.58569, saving model to modelo/resnet152v2.h5
# Epoch 2/20
# 73/73 [==============================] - 3s 39ms/step - loss: 0.9008 - categorical_accuracy: 0.6641 - val_loss: 0.2218 - val_categorical_accuracy: 0.9342
#
# Epoch 00002: val_loss improved from 0.58569 to 0.22175, saving model to modelo/resnet152v2.h5
# Epoch 3/20
# 73/73 [==============================] - 3s 40ms/step - loss: 0.4008 - categorical_accuracy: 0.8832 - val_loss: 0.1303 - val_categorical_accuracy: 0.9605
#
# Epoch 00003: val_loss improved from 0.22175 to 0.13030, saving model to modelo/resnet152v2.h5
# Epoch 4/20
# 73/73 [==============================] - 3s 39ms/step - loss: 0.3624 - categorical_accuracy: 0.8800 - val_loss: 0.0911 - val_categorical_accuracy: 0.9868
#
# Epoch 00004: val_loss improved from 0.13030 to 0.09107, saving model to modelo/resnet152v2.h5
# Epoch 5/20
# 73/73 [==============================] - 3s 39ms/step - loss: 0.2490 - categorical_accuracy: 0.9182 - val_loss: 0.0618 - val_categorical_accuracy: 0.9868
#
# Epoch 00005: val_loss improved from 0.09107 to 0.06176, saving model to modelo/resnet152v2.h5
# Epoch 6/20
# 73/73 [==============================] - 3s 39ms/step - loss: 0.2193 - categorical_accuracy: 0.9081 - val_loss: 0.0518 - val_categorical_accuracy: 0.9868
#
# Epoch 00006: val_loss improved from 0.06176 to 0.05182, saving model to modelo/resnet152v2.h5
# Epoch 7/20
# 73/73 [==============================] - 3s 39ms/step - loss: 0.2077 - categorical_accuracy: 0.9261 - val_loss: 0.0436 - val_categorical_accuracy: 1.0000
#
# Epoch 00007: val_loss improved from 0.05182 to 0.04359, saving model to modelo/resnet152v2.h5
# Epoch 8/20
# 73/73 [==============================] - 3s 39ms/step - loss: 0.1763 - categorical_accuracy: 0.9510 - val_loss: 0.0379 - val_categorical_accuracy: 1.0000
#
# Epoch 00008: val_loss improved from 0.04359 to 0.03791, saving model to modelo/resnet152v2.h5
# Epoch 9/20
# 73/73 [==============================] - 3s 39ms/step - loss: 0.1643 - categorical_accuracy: 0.9386 - val_loss: 0.0275 - val_categorical_accuracy: 1.0000
#
# Epoch 00009: val_loss improved from 0.03791 to 0.02750, saving model to modelo/resnet152v2.h5
# Epoch 10/20
# 73/73 [==============================] - 3s 39ms/step - loss: 0.1235 - categorical_accuracy: 0.9699 - val_loss: 0.0270 - val_categorical_accuracy: 1.0000
#
# Epoch 00010: val_loss improved from 0.02750 to 0.02703, saving model to modelo/resnet152v2.h5
# Epoch 11/20
# 73/73 [==============================] - 3s 39ms/step - loss: 0.0844 - categorical_accuracy: 0.9731 - val_loss: 0.0258 - val_categorical_accuracy: 1.0000
#
# Epoch 00011: val_loss improved from 0.02703 to 0.02584, saving model to modelo/resnet152v2.h5
# Epoch 12/20
# 73/73 [==============================] - 3s 40ms/step - loss: 0.1293 - categorical_accuracy: 0.9562 - val_loss: 0.0194 - val_categorical_accuracy: 1.0000
#
# Epoch 00012: val_loss improved from 0.02584 to 0.01943, saving model to modelo/resnet152v2.h5
# Epoch 13/20
# 73/73 [==============================] - 3s 39ms/step - loss: 0.0806 - categorical_accuracy: 0.9727 - val_loss: 0.0187 - val_categorical_accuracy: 1.0000
#
# Epoch 00013: val_loss improved from 0.01943 to 0.01871, saving model to modelo/resnet152v2.h5
# Epoch 14/20
# 73/73 [==============================] - 3s 39ms/step - loss: 0.1048 - categorical_accuracy: 0.9590 - val_loss: 0.0172 - val_categorical_accuracy: 1.0000
#
# Epoch 00014: val_loss improved from 0.01871 to 0.01716, saving model to modelo/resnet152v2.h5
# Epoch 15/20
# 73/73 [==============================] - 3s 39ms/step - loss: 0.0856 - categorical_accuracy: 0.9772 - val_loss: 0.0163 - val_categorical_accuracy: 1.0000
#
# Epoch 00015: val_loss improved from 0.01716 to 0.01625, saving model to modelo/resnet152v2.h5
# Epoch 16/20
# 73/73 [==============================] - 3s 39ms/step - loss: 0.0712 - categorical_accuracy: 0.9843 - val_loss: 0.0143 - val_categorical_accuracy: 1.0000
#
# Epoch 00016: val_loss improved from 0.01625 to 0.01425, saving model to modelo/resnet152v2.h5
# Epoch 17/20
# 73/73 [==============================] - 3s 39ms/step - loss: 0.0620 - categorical_accuracy: 0.9832 - val_loss: 0.0138 - val_categorical_accuracy: 1.0000
#
# Epoch 00017: val_loss improved from 0.01425 to 0.01379, saving model to modelo/resnet152v2.h5
# Epoch 18/20
# 73/73 [==============================] - 3s 39ms/step - loss: 0.0528 - categorical_accuracy: 0.9836 - val_loss: 0.0132 - val_categorical_accuracy: 1.0000
#
# Epoch 00018: val_loss improved from 0.01379 to 0.01323, saving model to modelo/resnet152v2.h5
# Epoch 19/20
# 73/73 [==============================] - 3s 39ms/step - loss: 0.0491 - categorical_accuracy: 0.9907 - val_loss: 0.0142 - val_categorical_accuracy: 1.0000
#
# Epoch 00019: val_loss did not improve from 0.01323
# Epoch 20/20
# 73/73 [==============================] - 3s 39ms/step - loss: 0.0617 - categorical_accuracy: 0.9831 - val_loss: 0.0113 - val_categorical_accuracy: 1.0000
#
# Epoch 00020: val_loss improved from 0.01323 to 0.01128, saving model to modelo/resnet152v2.h5
# Epoch 21/30
# 73/73 [==============================] - 42s 454ms/step - loss: 0.1092 - categorical_accuracy: 0.9560 - val_loss: 0.0216 - val_categorical_accuracy: 1.0000
#
# Epoch 00021: val_loss improved from inf to 0.02164, saving model to modelo/resnet152v2.h5
# Epoch 22/30
# 73/73 [==============================] - 7s 93ms/step - loss: 0.0650 - categorical_accuracy: 0.9771 - val_loss: 0.0334 - val_categorical_accuracy: 0.9868
#
# Epoch 00022: val_loss did not improve from 0.02164
# Epoch 23/30
# 73/73 [==============================] - 7s 93ms/step - loss: 0.0561 - categorical_accuracy: 0.9837 - val_loss: 0.0066 - val_categorical_accuracy: 1.0000
#
# Epoch 00023: val_loss improved from 0.02164 to 0.00659, saving model to modelo/resnet152v2.h5
# Epoch 24/30
# 73/73 [==============================] - 7s 93ms/step - loss: 0.0263 - categorical_accuracy: 0.9874 - val_loss: 0.0320 - val_categorical_accuracy: 0.9868
#
# Epoch 00024: val_loss did not improve from 0.00659
# Epoch 25/30
# 73/73 [==============================] - 7s 94ms/step - loss: 0.0436 - categorical_accuracy: 0.9855 - val_loss: 0.0110 - val_categorical_accuracy: 1.0000
#
# Epoch 00025: val_loss did not improve from 0.00659
# Epoch 26/30
# 73/73 [==============================] - 7s 94ms/step - loss: 0.0341 - categorical_accuracy: 0.9901 - val_loss: 0.0059 - val_categorical_accuracy: 1.0000
#
# Epoch 00026: val_loss improved from 0.00659 to 0.00593, saving model to modelo/resnet152v2.h5
# Epoch 27/30
# 73/73 [==============================] - 7s 94ms/step - loss: 0.0097 - categorical_accuracy: 0.9997 - val_loss: 0.0034 - val_categorical_accuracy: 1.0000
#
# Epoch 00027: val_loss improved from 0.00593 to 0.00339, saving model to modelo/resnet152v2.h5
# Epoch 28/30
# 73/73 [==============================] - 7s 94ms/step - loss: 0.0082 - categorical_accuracy: 0.9971 - val_loss: 0.0540 - val_categorical_accuracy: 0.9737
#
# Epoch 00028: val_loss did not improve from 0.00339
# Epoch 29/30
# 73/73 [==============================] - 7s 94ms/step - loss: 0.0426 - categorical_accuracy: 0.9858 - val_loss: 0.0173 - val_categorical_accuracy: 1.0000
#
# Epoch 00029: val_loss did not improve from 0.00339
# Epoch 30/30
# 73/73 [==============================] - 7s 94ms/step - loss: 0.0153 - categorical_accuracy: 0.9951 - val_loss: 0.0613 - val_categorical_accuracy: 0.9605
#
# Epoch 00030: val_loss did not improve from 0.00339
# 15/15 [==============================] - 2s 31ms/step
# {'model': 'resnet152v2', 'kappa': 0.9752874180724186, 'accuracy': 0.9826086956521739, 'recall': 0.9826086956521739, 'precision': 0.9833431700439373, 'f1': 0.9826151859135366, 'specificity': 0.994303281259803, 'roc': 0.9869201468466174}

# %%
resultados
# Out:
#                   model     kappa  accuracy    recall  precision        f1  \
# 0                 vgg16  0.583439  0.706897  0.706897   0.702102  0.703548
# 1           densenet201  0.877727  0.913793  0.913793   0.916971  0.912457
# 2          inception_v3  0.837971  0.887931  0.887931   0.895229  0.882963
# 3              xception  0.851631  0.896552  0.896552   0.899266  0.892744
# 4   inception_resnet_v2  0.851409  0.896552  0.896552   0.902625  0.895572
# 5                NASNet  0.817361  0.870690  0.870690   0.872278  0.871355
# 6           resnet152v2  0.839762  0.887931  0.887931   0.895675  0.880491
# 7                 vgg16  0.536401  0.681034  0.681034   0.665325  0.662627
# 8           densenet201  0.938889  0.956897  0.956897   0.959172  0.957162
# 9          inception_v3  0.891227  0.922414  0.922414   0.928263  0.923501
# 10             xception  0.902336  0.931034  0.931034   0.931199  0.931015
# 11  inception_resnet_v2  1.000000  1.000000  1.000000   1.000000  1.000000
# 12               NASNet  0.914246  0.939655  0.939655   0.939786  0.938490
# 13          resnet152v2  0.939171  0.956897  0.956897   0.958020  0.957095
# 14                vgg16  0.696462  0.784483  0.784483   0.798097  0.787888
# 15          densenet201  0.963245  0.974138  0.974138   0.974330  0.974047
# 16         inception_v3  0.963507  0.974138  0.974138   0.975862  0.974359
# 17             xception  0.975507  0.982759  0.982759   0.983457  0.982431
# 18  inception_resnet_v2  0.987759  0.991379  0.991379   0.991600  0.991312
# 19               NASNet  0.927197  0.948276  0.948276   0.951553  0.948834
# 20          resnet152v2  0.963276  0.974138  0.974138   0.974359  0.974071
# 21                vgg16  0.687432  0.782609  0.782609   0.771778  0.775531
# 22          densenet201  0.975285  0.982609  0.982609   0.982832  0.982615
# 23         inception_v3  0.950607  0.965217  0.965217   0.966055  0.964975
# 24             xception  0.975213  0.982609  0.982609   0.982832  0.982533
# 25  inception_resnet_v2  1.000000  1.000000  1.000000   1.000000  1.000000
# 26               NASNet  1.000000  1.000000  1.000000   1.000000  1.000000
# 27          resnet152v2  0.975287  0.982609  0.982609   0.983343  0.982615
#
#     specificity       roc
# 0      0.897338  0.762178
# 1      0.970356  0.930163
# 2      0.947585  0.893466
# 3      0.959144  0.903801
# 4      0.951747  0.909487
# 5      0.959452  0.898470
# 6      0.957969  0.901108
# 7      0.867409  0.730334
# 8      0.984142  0.964816
# 9      0.983071  0.941804
# 10     0.978173  0.942007
# 11     1.000000  1.000000
# 12     0.978841  0.945207
# 13     0.989708  0.964942
# 14     0.926197  0.839296
# 15     0.988949  0.977339
# 16     0.995454  0.981808
# 17     0.993352  0.983125
# 18     0.995800  0.991453
# 19     0.987223  0.965339
# 20     0.989153  0.977813
# 21     0.919047  0.814492
# 22     0.994200  0.986907
# 23     0.988503  0.973827
# 24     0.994303  0.981949
# 25     1.000000  1.000000
# 26     1.000000  1.000000
# 27     0.994303  0.986920

# %%
# Resultados de todas as iterações
resultados.to_csv('resultados/resultados.csv', index=False, header=True)

# %%
# Média dos resultados
def resultados_mean():
    df_mean = pd.DataFrame(columns = colunas_dataframe)

    for i in range(len(models)):
        lista_media = []
        lista_media.append(models[i].name)
        lista_media = lista_media + list(resultados.loc[resultados['model'] == models[i].name].mean())

        series_mean = pd.Series(lista_media, index = df_mean.columns)
        df_mean = df_mean.append(series_mean, ignore_index=True)
        
    return df_mean

# %%
# Média dos resultados
media_resultados = resultados_mean()
media_resultados.to_csv('resultados/media_resultados.csv', index=False, header=True)
media_resultados
# Out:
#                  model     kappa  accuracy    recall  precision        f1  \
# 0                vgg16  0.625934  0.738756  0.738756   0.734326  0.732399
# 1          densenet201  0.938787  0.956859  0.956859   0.958326  0.956570
# 2         inception_v3  0.910828  0.937425  0.937425   0.941352  0.936449
# 3             xception  0.926172  0.948238  0.948238   0.949189  0.947181
# 4  inception_resnet_v2  0.959792  0.971983  0.971983   0.973556  0.971721
# 5               NASNet  0.914701  0.939655  0.939655   0.940904  0.939670
# 6          resnet152v2  0.929374  0.950394  0.950394   0.952849  0.948568
#
#    specificity       roc
# 0     0.902497  0.786575
# 1     0.984412  0.964807
# 2     0.978653  0.947726
# 3     0.981243  0.952721
# 4     0.986887  0.975235
# 5     0.981379  0.952254
# 6     0.982783  0.957696

# %%
# Desvio Padrão dos resultados
def resultados_std():
    df_std = pd.DataFrame(columns = colunas_dataframe)

    for i in range(len(models)):
        lista_std = []
        lista_std.append(models[i].name)
        lista_std = lista_std + list(resultados.loc[resultados['model'] == models[i].name].std())

        series_std = pd.Series(lista_std, index = df_std.columns)
        df_std = df_std.append(series_std, ignore_index=True)
        
    return df_std

# %%
# Desvio padrão dos resultados
desvio_resultados = resultados_std()
desvio_resultados.to_csv('resultados/std_resultados.csv', index=False, header=True)
desvio_resultados
# Out:
#                  model     kappa  accuracy    recall  precision        f1  \
# 0                vgg16  0.078694  0.052791  0.052791   0.061289  0.059553
# 1          densenet201  0.043430  0.030639  0.030639   0.029255  0.031252
# 2         inception_v3  0.057878  0.039980  0.039980   0.036968  0.041949
# 3             xception  0.060452  0.042192  0.042192   0.041320  0.043654
# 4  inception_resnet_v2  0.072485  0.050451  0.050451   0.047453  0.050931
# 5               NASNet  0.075072  0.053142  0.053142   0.052652  0.052890
# 6          resnet152v2  0.061600  0.042994  0.042994   0.039532  0.046607
#
#    specificity       roc
# 0     0.026416  0.049387
# 1     0.010231  0.024804
# 2     0.021323  0.040092
# 3     0.016482  0.037800
# 4     0.023510  0.044017
# 5     0.017011  0.042400
# 6     0.016703  0.038788

# %% [markdown]
# # Resultados

# %% [markdown]
# ![title](imagens/result.png)

# %% [markdown]
# ![title](imagens/curvasssss.png)
#
# ![title](imagens/matriz_confusao.png)
#
# ![title](imagens/gradcam.png)

# %% [markdown]
# # Conclusões
